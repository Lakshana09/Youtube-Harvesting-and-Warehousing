# %%
import pandas as pd
from googleapiclient.discovery import build
import streamlit as st

# %%
Api_Key = "YOUR API KEY"
Api_Name = "youtube"
Api_Version = "v3"

# %%
def Api_connect():
    youtube = build(Api_Name, Api_Version, developerKey=Api_Key)
    return youtube

# %%
# Function to get the channel details
def get_channel_info(youtube, channel_id):
    request = youtube.channels().list(
        part="snippet,statistics,contentDetails",
        id=channel_id
    )
    response = request.execute()

    data = []
    for i in response["items"]:
        data.append({
            "Channel_Name": i["snippet"]["title"],
            "Channel_Id": i["id"],
            "Subscribers": i["statistics"]["subscriberCount"],
            "Views": i["statistics"]["viewCount"],
            "Total_videos": i["statistics"]["videoCount"],
            "Channel_description": i["snippet"]["description"],
            "Playlist_Id": i["contentDetails"]["relatedPlaylists"]["uploads"]
        })
    return data

# %%
youtube = build(Api_Name, Api_Version, developerKey=Api_Key)
channel_id = "UCCdoyJu5F5i_vkAu3sLU-Ww"
channel_data = get_channel_info(youtube, channel_id)

# %%
channel_data
# Out:
# [{'Channel_Name': 'Utharayini Dhurvas',
#   'Channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Subscribers': '48600',
#   'Views': '19506846',
#   'Total_videos': '48',
#   'Channel_description': 'Fashion,Beauty & Lifestyle',
#   'Playlist_Id': 'UUCdoyJu5F5i_vkAu3sLU-Ww'}]

# %%
def get_video_ids(youtube, channel_id):
    video_ids = []
    response = youtube.channels().list(
        id=channel_id,
        part='contentDetails'
    ).execute()
    playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token = None

    while True:
        response = youtube.playlistItems().list(
            part='snippet',
            playlistId=playlist_id,
            maxResults=50,
            pageToken=next_page_token
        ).execute()

        for item in response['items']:
            video_ids.append(item['snippet']['resourceId']['videoId'])

        next_page_token = response.get('nextPageToken')

        if not next_page_token:
            break

    return video_ids

# %%
Video_data = get_video_ids(youtube,channel_id)

# %%
Video_data
# Out:
# ['eRXM8WZl5xk',
#  'vLo8cPe45NE',
#  'hoD0RbCJxDs',
#  'AeoG_tJeLig',
#  'F5lL1XO2T-I',
#  'nV-ydgyAf34',
#  'mNXhF308Mn0',
#  'DHmtAXIkn0I',
#  'fGuUNUJ8nZk',
#  '-m1gcRrXRKY',
#  '1j63n_6lkhM',
#  'Iyo6bDWrOLw',
#  '8AYX7LjjoyI',
#  '_QiSqY0Mi5k',
#  'g9LpS1QfXhM',
#  'yWs2C1LHLzg',
#  'RAtEI1lgj-8',
#  'E-qxtYg-VXo',
#  'FXaUYLvP3ok',
#  'ZJNA8XuA0Og',
#  'MMCPzpiqJKM',
#  'JvJEUeU1r2Y',
#  'ffUnr2U8QYQ',
#  'Uvn-QllMQZQ',
#  'zhCYpjLTefQ',
#  'XYtD1IwGDEs',
#  'rH-QRRWE7bc',
#  'Jq-l_ItKg14',
#  'gs3oOJeyCLc',
#  'YZxqekV9vzs',
#  'aTWsuvFCXV4',
#  'feZXns7j6OI',
#  'Hy4INbbjYFk',
#  'AnIcNMhTVqE',
#  'ywvj9wQ1naE',
#  'HoG6iyVv_tw',
#  'NlyJdYQXjlk',
#  'y4Xjr2j0vLU',
#  'A6ZAqVIWlWI',
#  'J8BhHx4uh6Y',
#  'ZeRaMgbuiyo',
#  '40N5gHWU-8k',
#  'pv2vzRWg3Ac',
#  'urbS57f9ZxU',
#  'n1l7Iyznfvg',
#  'Zy_rQcpZMEA',
#  'J2bczj1A-W4',
#  'Ar_RvdaZ-7w']

# %%
import datetime
def get_Video_Details(youtube, video_ids):
    Video_data = []

    for video_id in video_ids:
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_id
        )
        response = request.execute()

        for item in response["items"]:
            publish_date_str = item['snippet']['publishedAt']
            publish_date = datetime.datetime.strptime(publish_date_str, '%Y-%m-%dT%H:%M:%SZ')
            formatted_publish_date = publish_date.strftime('%Y-%m-%d %H:%M:%S')


            data = {
                'Channel_Name': item['snippet']['channelTitle'],
                'channel_Id': item['snippet']['channelId'],
                'Video_Id': item['id'],
                'Title': item['snippet']['title'],
                'Tags': item['snippet'].get('tags'),
                'Thumbnail': item['snippet']['thumbnails']['default']['url'],
                'Description': item['snippet'].get('description'),
                'Publishdate': formatted_publish_date,
                'Duration': item['contentDetails']['duration'],
                'Views': item['statistics'].get('viewCount'),
                'Likes': item['statistics'].get('likeCount'),
                'Comments': item['statistics'].get('commentCount'),
                'Favorite_count': item['statistics'].get('favoriteCount'),
                'Definition': item['contentDetails']['definition'],
                'Caption_Status': item['contentDetails']['caption']
            }
            Video_data.append(data)
    return Video_data

# %%
video1 = get_Video_Details(youtube,Video_data)

# %%
video1
# Out:
# [{'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'eRXM8WZl5xk',
#   'Title': 'Holi 2024 ✨🌈',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/eRXM8WZl5xk/default.jpg',
#   'Description': '',
#   'Publishdate': '2024-03-26T01:43:02Z',
#   'Duration': 'PT17S',
#   'Views': '819',
#   'Likes': '77',
#   'Comments': '3',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'vLo8cPe45NE',
#   'Title': 'Love pannu 💜 dress from deepo_designers #tamil #tamilsong #love',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/vLo8cPe45NE/default.jpg',
#   'Description': '',
#   'Publishdate': '2024-03-20T17:13:00Z',
#   'Duration': 'PT22S',
#   'Views': '843',
#   'Likes': '62',
#   'Comments': '2',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'hoD0RbCJxDs',
#   'Title': 'Life with you ❤️🧿 #tamilsong #love',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/hoD0RbCJxDs/default.jpg',
#   'Description': '',
#   'Publishdate': '2024-03-15T16:19:15Z',
#   'Duration': 'PT12S',
#   'Views': '1572',
#   'Likes': '145',
#   'Comments': '6',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'AeoG_tJeLig',
#   'Title': 'Solo travel from Madurai to San Francisco ✈️ 15 hour layover ?',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/AeoG_tJeLig/default.jpg',
#   'Description': 'Follow me on Instagram: https://www.instagram.com/utharayini?igsh=MzRlODBiNWFlZA==\n\nMusic: B.there.4.u\nMusician: Jeff \n\n#tamilvlogs #vlog #travel',
#   'Publishdate': '2024-02-28T18:52:57Z',
#   'Duration': 'PT27M30S',
#   'Views': '5259',
#   'Likes': '210',
#   'Comments': '40',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'F5lL1XO2T-I',
#   'Title': 'Expectation vs reality 😂',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/F5lL1XO2T-I/default.jpg',
#   'Description': '',
#   'Publishdate': '2024-02-16T20:40:27Z',
#   'Duration': 'PT18S',
#   'Views': '3137',
#   'Likes': '158',
#   'Comments': '4',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'nV-ydgyAf34',
#   'Title': 'Shopping with mom❤️',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/nV-ydgyAf34/default.jpg',
#   'Description': '',
#   'Publishdate': '2024-02-06T17:08:12Z',
#   'Duration': 'PT19S',
#   'Views': '3372',
#   'Likes': '234',
#   'Comments': '5',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'mNXhF308Mn0',
#   'Title': '26 January 2024',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/mNXhF308Mn0/default.jpg',
#   'Description': '',
#   'Publishdate': '2024-01-26T16:10:58Z',
#   'Duration': 'PT12S',
#   'Views': '6041',
#   'Likes': '413',
#   'Comments': '14',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'DHmtAXIkn0I',
#   'Title': '🖤',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/DHmtAXIkn0I/default.jpg',
#   'Description': '',
#   'Publishdate': '2024-01-25T13:22:26Z',
#   'Duration': 'PT18S',
#   'Views': '9301',
#   'Likes': '712',
#   'Comments': '14',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'fGuUNUJ8nZk',
#   'Title': '20.08.2023🧿✨',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/fGuUNUJ8nZk/default.jpg',
#   'Description': '',
#   'Publishdate': '2024-01-24T23:31:12Z',
#   'Duration': 'PT16S',
#   'Views': '44594',
#   'Likes': '2452',
#   'Comments': '17',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': '-m1gcRrXRKY',
#   'Title': 'My love language ✨',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/-m1gcRrXRKY/default.jpg',
#   'Description': '',
#   'Publishdate': '2024-01-11T20:02:36Z',
#   'Duration': 'PT16S',
#   'Views': '15532405',
#   'Likes': '455106',
#   'Comments': '1727',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': '1j63n_6lkhM',
#   'Title': 'Marriage rituals 🍚🪔✨',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/1j63n_6lkhM/default.jpg',
#   'Description': '',
#   'Publishdate': '2024-01-09T22:14:11Z',
#   'Duration': 'PT23S',
#   'Views': '181270',
#   'Likes': '5920',
#   'Comments': '36',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'Iyo6bDWrOLw',
#   'Title': '2024 first mini vlog ✨🤍 #minivlog #whatieatinaday',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Iyo6bDWrOLw/default.jpg',
#   'Description': '',
#   'Publishdate': '2024-01-04T00:23:32Z',
#   'Duration': 'PT48S',
#   'Views': '91860',
#   'Likes': '2810',
#   'Comments': '23',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': '8AYX7LjjoyI',
#   'Title': 'First house move in US🏠❤️',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/8AYX7LjjoyI/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-12-23T04:35:37Z',
#   'Duration': 'PT52S',
#   'Views': '137816',
#   'Likes': '4254',
#   'Comments': '34',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': '_QiSqY0Mi5k',
#   'Title': 'Mini vlog #3🤍✨',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/_QiSqY0Mi5k/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-12-22T17:21:44Z',
#   'Duration': 'PT1M1S',
#   'Views': '66188',
#   'Likes': '2228',
#   'Comments': '29',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'g9LpS1QfXhM',
#   'Title': 'Mini vlog after ages 😌',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/g9LpS1QfXhM/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-11-14T05:15:38Z',
#   'Duration': 'PT45S',
#   'Views': '94663',
#   'Likes': '2201',
#   'Comments': '33',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'yWs2C1LHLzg',
#   'Title': 'Kanavo nijamo 🧿✨ #couple #longdistancerelationship #love',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/yWs2C1LHLzg/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-10-05T02:49:02Z',
#   'Duration': 'PT24S',
#   'Views': '2135508',
#   'Likes': '51749',
#   'Comments': '220',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'RAtEI1lgj-8',
#   'Title': '🪷💕',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/RAtEI1lgj-8/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-07-15T04:49:28Z',
#   'Duration': 'PT12S',
#   'Views': '44585',
#   'Likes': '1984',
#   'Comments': '16',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'E-qxtYg-VXo',
#   'Title': 'Shopping with mom 🛍️🥳🫶🏻',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/E-qxtYg-VXo/default.jpg',
#   'Description': 'Follow me on Instagram https://instagram.com/utharayini?igshid=Y2I2MzMwZWM3ZA==\n\nSuve the label Instagram page https://instagram.com/suve.thelabel?igshid=Y2I2MzMwZWM3ZA==\n\nMusic: Mornings\nMusician: Jeff Kaale',
#   'Publishdate': '2023-07-14T14:26:58Z',
#   'Duration': 'PT9M56S',
#   'Views': '12402',
#   'Likes': None,
#   'Comments': '44',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'FXaUYLvP3ok',
#   'Title': 'Olis vet day🏥🐾❤️',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/FXaUYLvP3ok/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-07-07T04:50:22Z',
#   'Duration': 'PT34S',
#   'Views': '29630',
#   'Likes': '708',
#   'Comments': '7',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'ZJNA8XuA0Og',
#   'Title': '✨VANITY TOUR✨in tamil | Utharayini Dhurvas',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/ZJNA8XuA0Og/default.jpg',
#   'Description': 'White small drawer organiser https://www.amazon.in/dp/B0B58ZNRY3?ref=ppx_pop_mob_ap_share\nAcrylic divided organiser https://www.amazon.in/dp/B0987SCK9G?ref=ppx_pop_mob_ap_share\nGold rim glass tray https://amzn.eu/d/fJNfrqU',
#   'Publishdate': '2023-06-14T14:47:06Z',
#   'Duration': 'PT17M58S',
#   'Views': '12075',
#   'Likes': None,
#   'Comments': '37',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'MMCPzpiqJKM',
#   'Title': 'Happy 26th Rowdy💕💋',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/MMCPzpiqJKM/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-05-27T16:42:36Z',
#   'Duration': 'PT42S',
#   'Views': '296004',
#   'Likes': None,
#   'Comments': '45',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'JvJEUeU1r2Y',
#   'Title': 'Finally 💍🧿💕🫶🏻 #wedding #tamilsong #madurai',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/JvJEUeU1r2Y/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-23T14:12:34Z',
#   'Duration': 'PT31S',
#   'Views': '124866',
#   'Likes': '3781',
#   'Comments': '11',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'ffUnr2U8QYQ',
#   'Title': 'Hey Sitaaaa 💕#tamil #tamilsong',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/ffUnr2U8QYQ/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-22T14:44:51Z',
#   'Duration': 'PT26S',
#   'Views': '74862',
#   'Likes': '1817',
#   'Comments': '15',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'Uvn-QllMQZQ',
#   'Title': '👑❤️ #tamil #tamilsongs #tamilsong #madurai',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Uvn-QllMQZQ/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-21T16:29:02Z',
#   'Duration': 'PT12S',
#   'Views': '20200',
#   'Likes': '937',
#   'Comments': '10',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'zhCYpjLTefQ',
#   'Title': 'Korean blush 💕 #kajabeauty #blush',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/zhCYpjLTefQ/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-21T07:13:20Z',
#   'Duration': 'PT31S',
#   'Views': '23924',
#   'Likes': '713',
#   'Comments': '7',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'XYtD1IwGDEs',
#   'Title': 'சென்னை vlog | packing,train travel,visa appointment and shopping 🧳🚉☀️🛍️🛂',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/XYtD1IwGDEs/default.jpg',
#   'Description': 'Follow me on Instagram https://instagram.com/utharayini?igshid=YmMyMTA2M2Y=\n\n\nPacking cube link https://www.amazon.in/dp/B09CNY94KH?ref=ppx_pop_mob_ap_share',
#   'Publishdate': '2023-04-21T05:23:36Z',
#   'Duration': 'PT13M47S',
#   'Views': '8481',
#   'Likes': None,
#   'Comments': '24',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'rH-QRRWE7bc',
#   'Title': 'Amazon find🛍️ #amazonfinds #amazon #haul #fashion',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/rH-QRRWE7bc/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-12T14:36:07Z',
#   'Duration': 'PT19S',
#   'Views': '25902',
#   'Likes': '831',
#   'Comments': '4',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'Jq-l_ItKg14',
#   'Title': 'Nykaa haul🛍️ #fashion #makeup #tamil #nykaa #nykaahaul',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Jq-l_ItKg14/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-12T06:33:04Z',
#   'Duration': 'PT33S',
#   'Views': '19100',
#   'Likes': None,
#   'Comments': '3',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'gs3oOJeyCLc',
#   'Title': '💄#lipstick #lipsticktutorial #makeup',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/gs3oOJeyCLc/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-10T15:13:35Z',
#   'Duration': 'PT15S',
#   'Views': '13847',
#   'Likes': None,
#   'Comments': '7',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'YZxqekV9vzs',
#   'Title': '#jatayuearthcenter #kerala',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/YZxqekV9vzs/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-08T15:06:28Z',
#   'Duration': 'PT9S',
#   'Views': '51075',
#   'Likes': None,
#   'Comments': '14',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'aTWsuvFCXV4',
#   'Title': 'My ROOM TOUR | Indian room tour | room tour in tamil 🏡💕',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/aTWsuvFCXV4/default.jpg',
#   'Description': 'Follow me on Instagram https://instagram.com/utharayini?igshid=YmMyMTA2M2Y=',
#   'Publishdate': '2023-04-08T05:00:08Z',
#   'Duration': 'PT7M14S',
#   'Views': '14369',
#   'Likes': None,
#   'Comments': '40',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'feZXns7j6OI',
#   'Title': 'Kedhar & Uthara pre engagement full video 20.01.2022 | Sourashtra couple',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/feZXns7j6OI/default.jpg',
#   'Description': '@kedharguhan \nPhotography by https://instagram.com/karthikha_photography?igshid=YmMyMTA2M2Y=\nFollow us on Instagram https://instagram.com/the_madurai_couple?igshid=YmMyMTA2M2Y=\n\nSong credits : yavvana from Sathya',
#   'Publishdate': '2023-04-06T07:19:55Z',
#   'Duration': 'PT3M40S',
#   'Views': '16964',
#   'Likes': None,
#   'Comments': '9',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'Hy4INbbjYFk',
#   'Title': 'Kedhar & Uthara pre engagement teaser 20.01.2022 💕🧿 #madurai #couple #engagement #teaser',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Hy4INbbjYFk/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-06T07:16:40Z',
#   'Duration': 'PT36S',
#   'Views': '53478',
#   'Likes': None,
#   'Comments': '3',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'AnIcNMhTVqE',
#   'Title': 'Everyday makeup in Tamil | using affordable products | no foundation look in Tamil💄✨',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/AnIcNMhTVqE/default.jpg',
#   'Description': 'Follow me on Instagram  https://instagram.com/utharayini?igshid=YmMyMTA2M2Y=\n\nProducts used - \nPonds super light gel moisturiser https://www.nykaa.com/ponds-super-light-gel-oil-free-moisturiser-with-hyaluronic-acid-vitamin-e/p/5526260?productId=502719&skuId=5526260&pps=3\nPonds bb cream https://www.nykaa.com/ponds-bb-cream-instant-spot-coverage-light-make-up-glow-natural/p/1498460?productId=1498460&pps=2&skuId=1498457\nInsight cosmetics concealer https://www.nykaa.com/insight-cosmetics-pro-conceale/p/368868?productId=368868&pps=3&skuId=368867\nSwiss beauty eyebrow palette https://www.googleadservices.com/pagead/aclk?sa=L&ai=DChcSEwiHxcHb4JP-AhXDkmYCHdZ-CF0YABAKGgJzbQ&ae=2&ohost=www.google.co.in&cid=CAASJuRomIdhROnLyl5f5_Qfh7t52m7Poqd3FNuvamUFUKD3AXsoDHbd&sig=AOD64_3a_XTfFDKUxaKIMzKMtAF8qyD10A&ctype=5&q=&ved=2ahUKEwiSg7zb4JP-AhVGXWwGHW43AZwQ5bgDKAB6BAgIEAo&adurl=\nEyetex Kajal supreme https://www.googleadservices.com/pagead/aclk?sa=L&ai=DChcSEwiR7umJ4ZP-AhVUkmYCHfVDC4UYABANGgJzbQ&ae=2&ohost=www.google.co.in&cid=CAASJuRoq8ttI8O_DnLK9rTg2AHOQiqFFrt1IpeT8rUiuNs901D8yQ0F&sig=AOD64_2mut1ZzfAyc1EKWisirOm2nV36HQ&ctype=5&q=&ved=2ahUKEwjwk-SJ4ZP-AhXjR2wGHRrpBIIQ5bgDKAB6BAgIEBc&adurl=\nSwiss beauty mascara https://www.nykaa.com/swiss-beauty-lift-curl-volume-lash-4d-mascara/p/6146487?productId=6146487&pps=2\nSwiss beauty matte lipstick https://www.nykaa.com/swiss-beauty-hd-matte-lipstick-lipstick/p/1231613?productId=1231613&pps=1&skuId=1231596\nSwiss beauty 2in1 lipliner  https://www.nykaa.com/swiss-beauty-two-in-one-lip-liner-lip-filler/p/7852035?productId=7852035&pps=4&skuId=7852018\n\nThank you for watching :)',
#   'Publishdate': '2023-04-06T05:47:01Z',
#   'Duration': 'PT3M28S',
#   'Views': '5575',
#   'Likes': None,
#   'Comments': '31',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'ywvj9wQ1naE',
#   'Title': 'Nighttime skin care 🌙✨ #skincareroutine #skincare',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/ywvj9wQ1naE/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-05T07:28:12Z',
#   'Duration': 'PT36S',
#   'Views': '29108',
#   'Likes': '801',
#   'Comments': '7',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'HoG6iyVv_tw',
#   'Title': '🤍🕊️✨ #fashion #masakali #madurai',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/HoG6iyVv_tw/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-04T07:55:35Z',
#   'Duration': 'PT11S',
#   'Views': '23120',
#   'Likes': '710',
#   'Comments': '5',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'NlyJdYQXjlk',
#   'Title': '🙈✨#tamilsong #tamil',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/NlyJdYQXjlk/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-02T15:07:36Z',
#   'Duration': 'PT10S',
#   'Views': '31093',
#   'Likes': '980',
#   'Comments': '13',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'y4Xjr2j0vLU',
#   'Title': 'Innaiki oru mini vlog🌞🥘🪔#tamil #food #tamilvlog #tamilvlogger',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/y4Xjr2j0vLU/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-04-01T14:27:42Z',
#   'Duration': 'PT50S',
#   'Views': '33877',
#   'Likes': '1265',
#   'Comments': '17',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'A6ZAqVIWlWI',
#   'Title': 'Hair care 🖤🖤 #haircare #hairproducts',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/A6ZAqVIWlWI/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-03-30T13:25:46Z',
#   'Duration': 'PT27S',
#   'Views': '17132',
#   'Likes': '465',
#   'Comments': '3',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'J8BhHx4uh6Y',
#   'Title': 'This outfit and the bgm 💖🤌🏻 #fashion #jimikkiponnu #tamil #tamilsong',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/J8BhHx4uh6Y/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-03-30T13:23:53Z',
#   'Duration': 'PT23S',
#   'Views': '18390',
#   'Likes': '546',
#   'Comments': '4',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'ZeRaMgbuiyo',
#   'Title': 'Recreating kathijas makeup look ⚡️ #samantha #makeuptutorial',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/ZeRaMgbuiyo/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-03-29T07:31:56Z',
#   'Duration': 'PT32S',
#   'Views': '15333',
#   'Likes': '510',
#   'Comments': '7',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': '40N5gHWU-8k',
#   'Title': 'My machini reel 🤍💚 #machini #tamil',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/40N5gHWU-8k/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-03-27T07:00:28Z',
#   'Duration': 'PT21S',
#   'Views': '50415',
#   'Likes': '1490',
#   'Comments': '10',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'pv2vzRWg3Ac',
#   'Title': 'Week in my life | Tamil vlog 🌈',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/pv2vzRWg3Ac/default.jpg',
#   'Description': 'Follow me on Instagram https://instagram.com/utharayini?igshid=YmMyMTA2M2Y= \n\nHope you liked the vlog ❤️',
#   'Publishdate': '2023-03-26T13:40:50Z',
#   'Duration': 'PT17M28S',
#   'Views': '10700',
#   'Likes': '284',
#   'Comments': '48',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'urbS57f9ZxU',
#   'Title': 'In the streets of Rome 🏛️ #rome #italy',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/urbS57f9ZxU/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-03-23T14:37:53Z',
#   'Duration': 'PT9S',
#   'Views': '29375',
#   'Likes': None,
#   'Comments': '10',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'n1l7Iyznfvg',
#   'Title': 'A year ago ❤️ #madurai #pooja',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/n1l7Iyznfvg/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-03-22T07:36:13Z',
#   'Duration': 'PT11S',
#   'Views': '29853',
#   'Likes': '613',
#   'Comments': '7',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'Zy_rQcpZMEA',
#   'Title': 'My casual fits ✨',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Zy_rQcpZMEA/default.jpg',
#   'Description': '',
#   'Publishdate': '2023-03-20T11:00:53Z',
#   'Duration': 'PT18S',
#   'Views': '23057',
#   'Likes': None,
#   'Comments': '16',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'J2bczj1A-W4',
#   'Title': 'My PRK(Lasik) eye surgery experience 👁️ how I went contact Lense and specs free.',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/J2bczj1A-W4/default.jpg',
#   'Description': 'Follow me on Instagram https://instagram.com/utharayini?igshid=YmMyMTA2M2Y=',
#   'Publishdate': '2023-03-18T06:28:25Z',
#   'Duration': 'PT13M1S',
#   'Views': '6930',
#   'Likes': '189',
#   'Comments': '36',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Utharayini Dhurvas',
#   'channel_Id': 'UCCdoyJu5F5i_vkAu3sLU-Ww',
#   'Video_Id': 'Ar_RvdaZ-7w',
#   'Title': '✨My go to makeup✨#doobey #makeup #makeuplook',
#   'Tags': ['Make-up look', 'Makeup', 'Doobey', 'Easy make-up'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Ar_RvdaZ-7w/default.jpg',
#   'Description': '',
#   'Publishdate': '2022-02-17T06:04:40Z',
#   'Duration': 'PT16S',
#   'Views': '26971',
#   'Likes': '466',
#   'Comments': '6',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
def get_comment_Details(youtube, video_ids):
    Comment_data = []
    try:
        for video_id in video_ids:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=50
            )
            response = request.execute()

            for item in response['items']:
                publish_date_str = item['snippet']['topLevelComment']['snippet']['publishedAt']
                publish_date = datetime.datetime.strptime(publish_date_str, '%Y-%m-%dT%H:%M:%SZ')
                formatted_publish_date = publish_date.strftime('%Y-%m-%d %H:%M:%S')
                data = {
                    'Comment_id': item['snippet']['topLevelComment']['id'],
                    'Video_id': item['snippet']['topLevelComment']['snippet']['videoId'],
                    'Comment_text': item['snippet']['topLevelComment']['snippet']['textDisplay'],
                    'Comment_Author': item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                    'Comment_Published':  formatted_publish_date
                }
                Comment_data.append(data)
    except Exception as e:
        print("Error retrieving comments:", e)
    return Comment_data

# %%
comment = get_comment_Details(youtube,Video_data)

# %%
comment
# Out:
# [{'Comment_id': 'UgxCIcqyyCQVt6Pgekx4AaABAg',
#   'Video_id': 'eRXM8WZl5xk',
#   'Comment_text': 'Hi sissy❤❤',
#   'Comment_Author': '@hariprasathvenkatesan7848',
#   'Comment_Published': '2024-03-28T17:09:45Z'},
#  {'Comment_id': 'UgzHluN0tujHuYc5nv14AaABAg',
#   'Video_id': 'eRXM8WZl5xk',
#   'Comment_text': 'Upload more diml sisyyy❤',
#   'Comment_Author': '@janvlogs_06',
#   'Comment_Published': '2024-03-26T11:31:22Z'},
#  {'Comment_id': 'UgxQXQcYkj7TcUxZu0h4AaABAg',
#   'Video_id': 'eRXM8WZl5xk',
#   'Comment_text': 'Super.  Enjoy ❤❤❤❤😘😘😘😘',
#   'Comment_Author': '@indumathikannan2264',
#   'Comment_Published': '2024-03-26T04:50:18Z'},
#  {'Comment_id': 'Ugx9ZACwZaU7bLDBYUd4AaABAg',
#   'Video_id': 'vLo8cPe45NE',
#   'Comment_text': 'Vlogs please❤❤',
#   'Comment_Author': '@hariprasathvenkatesan7848',
#   'Comment_Published': '2024-03-24T06:11:59Z'},
#  {'Comment_id': 'UgzQn5KHX1U00EpO4f54AaABAg',
#   'Video_id': 'vLo8cPe45NE',
#   'Comment_text': 'Long videos pottu 3weeks achi sis epo next video poduviga',
#   'Comment_Author': '@timonpumbaacouples3132',
#   'Comment_Published': '2024-03-21T03:37:21Z'},
#  {'Comment_id': 'Ugw-5WO5HUSs9MJEtRl4AaABAg',
#   'Video_id': 'hoD0RbCJxDs',
#   'Comment_text': 'Nice',
#   'Comment_Author': '@adi_official93',
#   'Comment_Published': '2024-03-19T16:13:07Z'},
#  {'Comment_id': 'UgzZZglP7I2TusJAkw14AaABAg',
#   'Video_id': 'hoD0RbCJxDs',
#   'Comment_text': 'Akka feeling really jealous 😢😢, should have born 10 years before❤❤',
#   'Comment_Author': '@hariprasathvenkatesan7848',
#   'Comment_Published': '2024-03-16T16:57:56Z'},
#  {'Comment_id': 'Ugy671JZudTzYK1ALTd4AaABAg',
#   'Video_id': 'hoD0RbCJxDs',
#   'Comment_text': 'Mena na palkar 🎈❤️😂',
#   'Comment_Author': '@thilagamtg',
#   'Comment_Published': '2024-03-15T17:23:32Z'},
#  {'Comment_id': 'Ugxhaa4uK865gigSJuV4AaABAg',
#   'Video_id': 'hoD0RbCJxDs',
#   'Comment_text': 'Looking cute ❤❤<br>Sending lots and lots of love...🎉',
#   'Comment_Author': '@jayasrisri7152',
#   'Comment_Published': '2024-03-15T17:02:01Z'},
#  {'Comment_id': 'UgyYEODVEzni8IzD3FB4AaABAg',
#   'Video_id': 'hoD0RbCJxDs',
#   'Comment_text': 'So ❤❤cute couples',
#   'Comment_Author': '@mirudhulasaiugva4315',
#   'Comment_Published': '2024-03-15T16:51:13Z'},
#  {'Comment_id': 'UgxkmP0MWy5aO7tXl194AaABAg',
#   'Video_id': 'hoD0RbCJxDs',
#   'Comment_text': 'Super b. So cute',
#   'Comment_Author': '@indumathikannan2264',
#   'Comment_Published': '2024-03-15T16:47:37Z'},
#  {'Comment_id': 'UgxD6lEQepfyBgI1ajN4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'But still u looking cute in this video 😸',
#   'Comment_Author': '@vaideshwari.vvaideshwari.v3309',
#   'Comment_Published': '2024-03-20T12:41:25Z'},
#  {'Comment_id': 'UgyA8R7ByUOeJnO4_4l4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Do Regularly 🙏🏻😢',
#   'Comment_Author': '@sowmiyasureshkumar3882',
#   'Comment_Published': '2024-03-16T06:43:11Z'},
#  {'Comment_id': 'UgwdEoocXniPNoBVAH54AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Nice 😍😍😍',
#   'Comment_Author': '@nathiyababy2194',
#   'Comment_Published': '2024-03-06T11:36:08Z'},
#  {'Comment_id': 'Ugy_VOZlfQhUL56WDc94AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': '😍',
#   'Comment_Author': '@veshali2511',
#   'Comment_Published': '2024-03-03T06:04:34Z'},
#  {'Comment_id': 'Ugz_4m9ZvYRy7XL50h14AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Love your vdos sister please do more vlogs waiting for that😊❤ love from Kerala',
#   'Comment_Author': '@nandanakjayesh2659',
#   'Comment_Published': '2024-03-01T19:10:51Z'},
#  {'Comment_id': 'Ugx5KXO2Rcg4yUnplPp4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'You were watching juhith vlogs right??????',
#   'Comment_Author': '@nalini264',
#   'Comment_Published': '2024-03-01T14:04:19Z'},
#  {'Comment_id': 'UgwjqOiQl9rvAB6UVCR4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Wow super nice place',
#   'Comment_Author': '@Amman_vellore_angalammanthunai',
#   'Comment_Published': '2024-03-01T13:47:17Z'},
#  {'Comment_id': 'Ugy4_SgEpbJcwae3Ksd4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'I love ur hair akka🥺❤️',
#   'Comment_Author': '@bakiyakumar5277',
#   'Comment_Published': '2024-03-01T07:38:06Z'},
#  {'Comment_id': 'UgyuNRePbHHrvLADnkt4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Wholesomeee!❤',
#   'Comment_Author': '@dheephsiaravinth',
#   'Comment_Published': '2024-02-29T20:09:36Z'},
#  {'Comment_id': 'UgxVNtI8ffRSsY9c8zt4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Finally😍❤️\u200d🔥',
#   'Comment_Author': '@bleeblee6',
#   'Comment_Published': '2024-02-29T16:02:40Z'},
#  {'Comment_id': 'UgxMkeZ6fTa3nKp7iNV4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Omg madurai vlog ah please upload that',
#   'Comment_Author': '@deepika_248',
#   'Comment_Published': '2024-02-29T12:38:51Z'},
#  {'Comment_id': 'Ugw2zBe77C-PFXb5XJt4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Pls vlog apo apo',
#   'Comment_Author': '@devipriya6485',
#   'Comment_Published': '2024-02-29T11:25:21Z'},
#  {'Comment_id': 'Ugx8FvsETtnCih_iOSp4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Akka anna kitta ketu ungala mari girls ah lam epudi crt pandra thunu ketu solunga please❤❤',
#   'Comment_Author': '@hariprasathvenkatesan7848',
#   'Comment_Published': '2024-02-29T08:10:58Z'},
#  {'Comment_id': 'Ugz85Bbm64ojykNmI7N4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Congrats for 50 k soon akka 🤩',
#   'Comment_Author': '@user-ku8vo5pn7v',
#   'Comment_Published': '2024-02-29T08:08:07Z'},
#  {'Comment_id': 'UgxJv7pg2tst3xpkHaN4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Waiting for next volg🤩💕',
#   'Comment_Author': '@user-ku8vo5pn7v',
#   'Comment_Published': '2024-02-29T08:06:14Z'},
#  {'Comment_id': 'Ugy3PRhcwIax2SdQBT94AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'what video editing tool do you use?',
#   'Comment_Author': '@beyourself3647',
#   'Comment_Published': '2024-02-29T07:45:57Z'},
#  {'Comment_id': 'UgyLaItEy3LY3G-Ob9J4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Wait next vlog❤',
#   'Comment_Author': '@nidhinanidhi8604',
#   'Comment_Published': '2024-02-29T05:15:16Z'},
#  {'Comment_id': 'UgyXaM60ArV1bKrrdnJ4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Hi. At 10.20 you are mentioning it as Indian Embassy....well it&#39;s not Embassy....it&#39;s the Immigration, where they stamp on your Passport to mention that you have departed from a Indian Airport........ Embassy is the office of a country where they issue the Visa.....Just wanted to say this.... nothing sarcastic......But your videos are cute and nice...',
#   'Comment_Author': '@balajiganesan2538',
#   'Comment_Published': '2024-02-29T03:02:19Z'},
#  {'Comment_id': 'UgzhbBymE2WoxMMKm0V4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Waiting for ur next vlog Akka❤️ u looking gorgeous 🥰',
#   'Comment_Author': '@Mathu_Kowshi',
#   'Comment_Published': '2024-02-28T23:56:48Z'},
#  {'Comment_id': 'Ugwx6SC3HqENjsVODXp4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'Sis, ung husband looks like, insta influencer Roshan🎉',
#   'Comment_Author': '@roshanakther7646',
#   'Comment_Published': '2024-02-28T19:56:14Z'},
#  {'Comment_id': 'UgwysmQLs7aD-j6VvdV4AaABAg',
#   'Video_id': 'AeoG_tJeLig',
#   'Comment_text': 'PLEASE USE ENGLISH OR HINDI...<a href="UCkszU2WH9gy1mb0dV-11UJg/W8IfY_bwAfiPq7IPvNCA2AU"></a>',
#   'Comment_Author': '@sethg1403',
#   'Comment_Published': '2024-02-28T18:57:56Z'},
#  {'Comment_id': 'Ugw17Rtowz0omNjZM0h4AaABAg',
#   'Video_id': 'F5lL1XO2T-I',
#   'Comment_text': 'Ur love story tell me',
#   'Comment_Author': '@user-fu3vz6sq9t',
#   'Comment_Published': '2024-03-10T15:01:54Z'},
#  {'Comment_id': 'UgzcIbPDcKMSSvQzvCN4AaABAg',
#   'Video_id': 'F5lL1XO2T-I',
#   'Comment_text': 'Vlog 😢',
#   'Comment_Author': '@user-ku8vo5pn7v',
#   'Comment_Published': '2024-02-19T19:56:09Z'},
#  {'Comment_id': 'UgzyezpvuH-HrxJdnkZ4AaABAg',
#   'Video_id': 'F5lL1XO2T-I',
#   'Comment_text': 'You both are so cute 🥰❤',
#   'Comment_Author': '@mirudhulasaiugva4315',
#   'Comment_Published': '2024-02-17T13:43:40Z'},
#  {'Comment_id': 'UgxDe9Bw4j7MYEdyi_14AaABAg',
#   'Video_id': 'nV-ydgyAf34',
#   'Comment_text': 'Waiting for your vlogs',
#   'Comment_Author': '@mirudhulasaiugva4315',
#   'Comment_Published': '2024-02-17T13:44:30Z'},
#  {'Comment_id': 'UgwbAaXkdaWjIr9R1I14AaABAg',
#   'Video_id': 'nV-ydgyAf34',
#   'Comment_text': 'Maai your love story upload keruvo',
#   'Comment_Author': '@rksai2013',
#   'Comment_Published': '2024-02-10T06:52:34Z'},
#  {'Comment_id': 'Ugx8LmpeCQ_JOXncDwd4AaABAg',
#   'Video_id': 'nV-ydgyAf34',
#   'Comment_text': 'Akka vlog 🫠',
#   'Comment_Author': '@user-ku8vo5pn7v',
#   'Comment_Published': '2024-02-09T09:16:06Z'},
#  {'Comment_id': 'Ugy0-bScppGStDqdySJ4AaABAg',
#   'Video_id': 'nV-ydgyAf34',
#   'Comment_text': 'Khub bhalo🫶🌸👌🏻love ur bindi♥️',
#   'Comment_Author': '@adi_official93',
#   'Comment_Published': '2024-02-08T01:45:50Z'},
#  {'Comment_id': 'UgzBeNJFphHqyGkwiVt4AaABAg',
#   'Video_id': 'nV-ydgyAf34',
#   'Comment_text': 'Missing your madurai vlogs<br>Dont know why people are missing these life and living in abroad.😢',
#   'Comment_Author': '@DoodleGirl20',
#   'Comment_Published': '2024-02-06T17:14:30Z'},
#  {'Comment_id': 'UgxTX5JuRZldUYIpwgl4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': 'So cute 🥰',
#   'Comment_Author': '@mirudhulasaiugva4315',
#   'Comment_Published': '2024-02-17T13:45:08Z'},
#  {'Comment_id': 'Ugwu7KAGgHjHd9JWHTd4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': 'Akka neraiya vlogs and shorts podunga',
#   'Comment_Author': '@nsharipriya0552',
#   'Comment_Published': '2024-02-01T10:37:20Z'},
#  {'Comment_id': 'Ugw5uKa_yiXw3Q9_Qph4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': 'I’m friend of your dad Mr.DSJ',
#   'Comment_Author': '@gdperumal',
#   'Comment_Published': '2024-02-01T00:08:43Z'},
#  {'Comment_id': 'UgwaJhViqE09AF3RDbJ4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': 'Presently my ship @Houston',
#   'Comment_Author': '@gdperumal',
#   'Comment_Published': '2024-02-01T00:07:31Z'},
#  {'Comment_id': 'Ugyjp7h5JgfG4NtRQVl4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': 'Where is the place ?',
#   'Comment_Author': '@gdperumal',
#   'Comment_Published': '2024-02-01T00:06:05Z'},
#  {'Comment_id': 'UgzN3uFUS57iuBBVyzV4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': '❤❤❤❤❤',
#   'Comment_Author': '@subhashchandra8865',
#   'Comment_Published': '2024-01-31T02:15:11Z'},
#  {'Comment_id': 'UgywlyI_YJEt55_Aj9p4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': 'Wow look amazing 😊',
#   'Comment_Author': '@muhammednaser8531',
#   'Comment_Published': '2024-01-29T16:37:07Z'},
#  {'Comment_id': 'UgxbN-UAxz2OsASsAON4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': 'Kitni Sundar wow',
#   'Comment_Author': '@anonymousbee',
#   'Comment_Published': '2024-01-27T18:08:54Z'},
#  {'Comment_id': 'UgzDUYPiOylUkQife5V4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': 'Super',
#   'Comment_Author': '@abhimanyubhuyan1871',
#   'Comment_Published': '2024-01-27T16:15:41Z'},
#  {'Comment_id': 'UgwP4HV7rb1m5xSFEjR4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': 'I love you 😘',
#   'Comment_Author': '@syedbaberali3609',
#   'Comment_Published': '2024-01-27T07:47:09Z'},
#  {'Comment_id': 'Ugy5O7KPxZHBx4AuaTR4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': 'What&#39;s your age sister please reply',
#   'Comment_Author': '@user-zi9cj3qm7k',
#   'Comment_Published': '2024-01-27T06:48:44Z'},
#  {'Comment_id': 'UgzFSns4mQO9Z9_XNXJ4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': 'we need your love story plsss',
#   'Comment_Author': '@user-xc1ng3zb2j',
#   'Comment_Published': '2024-01-27T04:10:10Z'},
#  {'Comment_id': 'Ugx17oaxOwxtF-U8WHB4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': '❤❤',
#   'Comment_Author': '@ImrankhanImrankhan-pk6isk',
#   'Comment_Published': '2024-01-26T17:27:59Z'},
#  {'Comment_id': 'Ugwx69oUz95CpGNf1HV4AaABAg',
#   'Video_id': 'mNXhF308Mn0',
#   'Comment_text': 'Bahoot khubsurat ho 😂❤',
#   'Comment_Author': '@safimohammad8412',
#   'Comment_Published': '2024-01-26T17:22:25Z'},
#  {'Comment_id': 'UgwHsG-2TkxbfewzHuR4AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': 'Lovely 🌹😍',
#   'Comment_Author': '@mirudhulasaiugva4315',
#   'Comment_Published': '2024-02-17T13:45:35Z'},
#  {'Comment_id': 'UgxqtGhMv4jeV_Oj_t54AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': 'So pretty',
#   'Comment_Author': '@muhammednaser8531',
#   'Comment_Published': '2024-01-30T05:53:17Z'},
#  {'Comment_id': 'UgxGDAo--xQ7zuWr58t4AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': '😅😅',
#   'Comment_Author': '@Vinayyadav-tc7jv',
#   'Comment_Published': '2024-01-27T03:10:52Z'},
#  {'Comment_id': 'Ugwp4cqB1cvR8F9XiaB4AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': 'Super 🎉🎉',
#   'Comment_Author': '@rajaduraitnfrs9595',
#   'Comment_Published': '2024-01-26T15:47:26Z'},
#  {'Comment_id': 'UgwPci6JyDTRTnzWl6B4AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': 'Beautiful but sticker should be red colour in forehead',
#   'Comment_Author': '@hanvika2221',
#   'Comment_Published': '2024-01-26T04:47:16Z'},
#  {'Comment_id': 'UgyNwUihrIm8BJk1AIl4AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': 'I loved the couple shorts ❤❤ love from nepal',
#   'Comment_Author': '@shivamsaaho6570',
#   'Comment_Published': '2024-01-26T04:20:04Z'},
#  {'Comment_id': 'UgwFLTKdWmScvhwdCG94AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': 'Super 👌',
#   'Comment_Author': '@user-ds4no1mp2f',
#   'Comment_Published': '2024-01-25T19:40:38Z'},
#  {'Comment_id': 'UgwnIDkg608O5QH4raN4AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': '<a href="https://youtube.com/@CUTE.janan87?si=y-Ha0r1M4wp86ypD">https://youtube.com/@CUTE.janan87?si=y-Ha0r1M4wp86ypD</a>',
#   'Comment_Author': '@CUTE.janan87',
#   'Comment_Published': '2024-01-25T15:35:30Z'},
#  {'Comment_id': 'UgzO69wbdWQqxIt21X94AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': 'Just looking like a wow ❤️❤️❤️',
#   'Comment_Author': '@Priyanka_.3',
#   'Comment_Published': '2024-01-25T15:25:36Z'},
#  {'Comment_id': 'UgwIBzt7wQt9TWQXh9t4AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': 'Honeymoon ki video kb dal rahay ho paiso k leye bhain k loro',
#   'Comment_Author': '@MadVideos007',
#   'Comment_Published': '2024-01-25T15:04:06Z'},
#  {'Comment_id': 'UgxYFa0RL7EsvKwcLTJ4AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': 'Chutiyapa vines',
#   'Comment_Author': '@Yha.113.uahz-_86_',
#   'Comment_Published': '2024-01-25T14:51:12Z'},
#  {'Comment_id': 'UgxwVVJrcYmNLi4o-yt4AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': '😮',
#   'Comment_Author': '@ActuallyAishwarya',
#   'Comment_Published': '2024-01-25T14:06:21Z'},
#  {'Comment_id': 'Ugyd9i8_fCw8-6VhCyt4AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': '❤ gorgeous 😍🥰',
#   'Comment_Author': '@sharmila2103',
#   'Comment_Published': '2024-01-25T13:47:23Z'},
#  {'Comment_id': 'UgwEBIG_LlZ3uuXy_ZF4AaABAg',
#   'Video_id': 'DHmtAXIkn0I',
#   'Comment_text': 'Speechless 🙊',
#   'Comment_Author': '@gauravmalhotra9917',
#   'Comment_Published': '2024-01-25T13:27:42Z'},
#  {'Comment_id': 'UgxkVu43mhkqJT7vAN14AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': 'Can you come to live',
#   'Comment_Author': '@mirudhulasaiugva4315',
#   'Comment_Published': '2024-02-17T13:46:26Z'},
#  {'Comment_id': 'Ugyev5E-nGKjBzPrwwJ4AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': 'Sweet couple ❤❤❤❤made for each other',
#   'Comment_Author': '@anandnishad9068',
#   'Comment_Published': '2024-01-25T18:05:48Z'},
#  {'Comment_id': 'UgzFbkQAIQhNvwhvZS54AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': 'Nice',
#   'Comment_Author': '@Indianyoutubersumalini',
#   'Comment_Published': '2024-01-25T12:07:32Z'},
#  {'Comment_id': 'Ugw9mm6uViWIOknW8nx4AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': 'U and ur husband are looking 😍 made for each other 💓',
#   'Comment_Author': '@nsharipriya0552',
#   'Comment_Published': '2024-01-25T11:58:00Z'},
#  {'Comment_id': 'UgyvVKXMjdk5jPHUjUF4AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': 'Akka marriage video',
#   'Comment_Author': '@user-uk2bk3wk5p',
#   'Comment_Published': '2024-01-25T11:44:57Z'},
#  {'Comment_id': 'UgytlINbwWdv_WjdqUZ4AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': '❤❤❤❤❤',
#   'Comment_Author': '@user-tc5kd9vl9u',
#   'Comment_Published': '2024-01-25T09:37:02Z'},
#  {'Comment_id': 'UgztWAStvL6YG2mEa-14AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': 'Neenga sowrastira vaa',
#   'Comment_Author': '@roopinivenkataraman9082',
#   'Comment_Published': '2024-01-25T08:53:26Z'},
#  {'Comment_id': 'Ugywd6_4ADbm4y7y9SN4AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': 'So sweet 🎉🎉🎉',
#   'Comment_Author': '@vipneshbaghel5426',
#   'Comment_Published': '2024-01-25T07:16:38Z'},
#  {'Comment_id': 'Ugw4iBDXu4kDNEuZ8O94AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': '🥰🥰🥰🥰🥰🥰🥰🥰',
#   'Comment_Author': '@alritaha4209',
#   'Comment_Published': '2024-01-25T06:31:05Z'},
#  {'Comment_id': 'UgwjXWSuAf64i56SIrF4AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': '❤❤❤❤',
#   'Comment_Author': '@rajasreelekshmi9453',
#   'Comment_Published': '2024-01-25T04:20:50Z'},
#  {'Comment_id': 'UgzqBYOIFtk6QDWJZD14AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': 'Unga pair enaku romba pudikum akka ❤❤❤❤',
#   'Comment_Author': '@Latharaja314',
#   'Comment_Published': '2024-01-25T04:20:33Z'},
#  {'Comment_id': 'UgwxkhoxUm1lTktI0-N4AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': 'Unga love story solunga relative ah avanga',
#   'Comment_Author': '@karthickfootballer2397',
#   'Comment_Published': '2024-01-25T03:46:54Z'},
#  {'Comment_id': 'UgxJ39XDwQ0rsC_VpHZ4AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': '😍😍😍😍😍😍😍😍😍',
#   'Comment_Author': '@nooranipathan0707',
#   'Comment_Published': '2024-01-25T02:24:12Z'},
#  {'Comment_id': 'Ugy0zr-VsVK9g5OslJJ4AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': 'Please didi promotion kar dijiye 🙏🙏🙏🙏',
#   'Comment_Author': '@With_Sharma_Gaming_3-10',
#   'Comment_Published': '2024-01-25T01:05:07Z'},
#  {'Comment_id': 'UgzCK4tV1cf8W9yCcjx4AaABAg',
#   'Video_id': 'fGuUNUJ8nZk',
#   'Comment_text': 'I&#39;m soooo happy for this . I think I&#39;m the one who has eagerly waited u ppl to get married soon 💕and you guys  made it 😚 it&#39;s been 5 months 🌚luvyeww always 🫂👩\u200d❤️\u200d👩',
#   'Comment_Author': '@Priyanka_.3',
#   'Comment_Published': '2024-01-25T00:59:50Z'},
#  {'Comment_id': 'Ugy-tqfFHDnj_NRzlKt4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Great 🎉🎉🎉',
#   'Comment_Author': '@gdperumal',
#   'Comment_Published': '2024-01-31T05:08:26Z'},
#  {'Comment_id': 'UgzI-QuRiCxIInYpbYd4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Tasty lag rha khana❤',
#   'Comment_Author': '@sahilverma7472',
#   'Comment_Published': '2024-01-26T01:33:24Z'},
#  {'Comment_id': 'UgwsF7emt2UISLl3qp94AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Love 💕😘❤',
#   'Comment_Author': '@ranaabid2963',
#   'Comment_Published': '2024-01-25T20:52:28Z'},
#  {'Comment_id': 'Ugz4DZdQuyYiAl_93gF4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'God bless you both',
#   'Comment_Author': '@crazykraftedits',
#   'Comment_Published': '2024-01-25T20:22:29Z'},
#  {'Comment_id': 'UgzKCjGCYEZfT0SAGuB4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Kas😢. Kya nashib he bhai',
#   'Comment_Author': '@mr.7teen956',
#   'Comment_Published': '2024-01-25T20:19:21Z'},
#  {'Comment_id': 'UgxLBTLGidesyOf40DV4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'In real life reverse the character of this reel 😂😂😂😂',
#   'Comment_Author': '@syedashwaq3341',
#   'Comment_Published': '2024-01-25T19:58:38Z'},
#  {'Comment_id': 'UgyhtAA0dQS15aVAEtF4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Suru me sab acha lgta h bro',
#   'Comment_Author': '@deepaksinha6424',
#   'Comment_Published': '2024-01-25T19:50:26Z'},
#  {'Comment_id': 'UgyxR8N_GDHBNxvzSpx4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Bhai yah sab social media per Hai Piche ki kahani bahut Khatarnak hoti hai😢😢',
#   'Comment_Author': '@furkanhashmi09',
#   'Comment_Published': '2024-01-25T19:37:26Z'},
#  {'Comment_id': 'UgwLxRbhAzKoT1e0JBN4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Wife be like.   Me cooking.. u y kissing 😂😂 if mood comming...  i stop cooking . u start fucking.',
#   'Comment_Author': '@JAN-E-MANN',
#   'Comment_Published': '2024-01-25T19:32:37Z'},
#  {'Comment_id': 'UgyNFhQWp3408KMpuX14AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Meri cooking master Kaha ho tum I really miss U',
#   'Comment_Author': '@mdshabaz3132',
#   'Comment_Published': '2024-01-25T19:28:02Z'},
#  {'Comment_id': 'Ugx76VKlgl8QF-v-YGJ4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Room k andar kya karre uska b video banao',
#   'Comment_Author': '@shaiksohail1947',
#   'Comment_Published': '2024-01-25T19:23:21Z'},
#  {'Comment_id': 'UgwUeL67GeqIac_azWN4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Lol😂😂😂😂😂😂😂😂😂',
#   'Comment_Author': '@mdjoy3288',
#   'Comment_Published': '2024-01-25T19:19:21Z'},
#  {'Comment_id': 'UgxvPACSNx0Eh4sP6hx4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Yeh sabji latring jaisa kyu lag lag raha  😭😭😭',
#   'Comment_Author': '@Stfuwacky',
#   'Comment_Published': '2024-01-25T19:13:13Z'},
#  {'Comment_id': 'UgwXx_IFmTLQZtfres14AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': '🧿♥️🤗',
#   'Comment_Author': '@debidullaljena5492',
#   'Comment_Published': '2024-01-25T19:03:10Z'},
#  {'Comment_id': 'UgxZoOM9U41KRSEZNyd4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Bhai aisa kaamwali bai to mai bhi deserve karta hu😢😢',
#   'Comment_Author': '@Colorenew',
#   'Comment_Published': '2024-01-25T19:01:37Z'},
#  {'Comment_id': 'Ugw7x7Xmh__OwlPhzrx4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Bhai Kuch mahenee bith ne de bhai phir pura khaana samee suth nikalegi III 😂😂😂😂😂😂😂',
#   'Comment_Author': '@mohammedshahebaaz',
#   'Comment_Published': '2024-01-25T18:50:36Z'},
#  {'Comment_id': 'Ugw8MGS5oE-3e3sh7kd4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Cute',
#   'Comment_Author': '@strangersayz2749',
#   'Comment_Published': '2024-01-25T18:49:03Z'},
#  {'Comment_id': 'Ugy83J0Foqm9FSy8ANh4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'सारे डिश 20 मिनट के अंदर बन जाता है अगर प्यार है तो 5 घंटे बनने वाले डिश पर वीडियो बनाए',
#   'Comment_Author': '@user-hr8oo2ln6c',
#   'Comment_Published': '2024-01-25T18:43:21Z'},
#  {'Comment_id': 'UgxWeXsHdgMnMyfM4ux4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Mujhe kyo thoda😢',
#   'Comment_Author': '@dhirendrakumar276',
#   'Comment_Published': '2024-01-25T18:41:41Z'},
#  {'Comment_id': 'UgwAePRiee7db_wIzdJ4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Aise wife muje b mile .. bodybuilder hu .. bht zyada khana chhye 😂😂',
#   'Comment_Author': '@ananthswamy1975',
#   'Comment_Published': '2024-01-25T18:33:52Z'},
#  {'Comment_id': 'UgyslL6EARC4pq4cMM54AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'You both are the most couple. ❤stay blessed bro and bhabhi.',
#   'Comment_Author': '@BossGamingOFAYT',
#   'Comment_Published': '2024-01-25T18:32:31Z'},
#  {'Comment_id': 'Ugw2X9-ruaktTjklq2N4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'I hate cooking and feel like who invented this cooking and that too 3 times a day 😂',
#   'Comment_Author': '@radhakathare8025',
#   'Comment_Published': '2024-01-25T18:31:38Z'},
#  {'Comment_id': 'UgyhsrBOB5ZxzIA5jJl4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Lucky guy',
#   'Comment_Author': '@khalidahmad2482',
#   'Comment_Published': '2024-01-25T18:24:53Z'},
#  {'Comment_id': 'UgzTOv_RQWlf0m0iUR54AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'huppy🎉',
#   'Comment_Author': '@AshokTiwari-vw4nz',
#   'Comment_Published': '2024-01-25T18:23:17Z'},
#  {'Comment_id': 'Ugwf0HMdST2mLbjtmbV4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'happy',
#   'Comment_Author': '@AshokTiwari-vw4nz',
#   'Comment_Published': '2024-01-25T18:22:44Z'},
#  {'Comment_id': 'Ugwyufsc8ED2zNebes54AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Sunder wife mile na mile but ese testi khana banana mil Jaye bhut hai life time ❤🫰🤞🧿🙌🙌🙌😋😋🤤',
#   'Comment_Author': '@viicky1314',
#   'Comment_Published': '2024-01-25T18:21:32Z'},
#  {'Comment_id': 'UgwAsMCFpK9CVVnzSIt4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Chod',
#   'Comment_Author': '@lonetraveller8627',
#   'Comment_Published': '2024-01-25T18:13:36Z'},
#  {'Comment_id': 'UgzsVy5Lk-fFu7ZTNGx4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'A few moments earlier...😂😂😂',
#   'Comment_Author': '@rashidrizvi2000',
#   'Comment_Published': '2024-01-25T18:13:28Z'},
#  {'Comment_id': 'UgypO0__JANnCAGRPH14AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Hey bhagwan aisi biwi chahiye 😙🙈',
#   'Comment_Author': '@ARMY_GAMEING',
#   'Comment_Published': '2024-01-25T18:11:02Z'},
#  {'Comment_id': 'UgyLpagn_TnEMwpwUR94AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'love ❤❤',
#   'Comment_Author': '@foysalahmedniloy8485',
#   'Comment_Published': '2024-01-25T17:57:51Z'},
#  {'Comment_id': 'UgwggdpHyCoRo1GP7uN4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Very nice video',
#   'Comment_Author': '@krishanughosh4353',
#   'Comment_Published': '2024-01-25T17:38:14Z'},
#  {'Comment_id': 'UgwRFjNshJFPpnm8uMx4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': '30 second video for , how to maintain the extra time in bed.',
#   'Comment_Author': '@Bruisader',
#   'Comment_Published': '2024-01-25T17:33:57Z'},
#  {'Comment_id': 'UgzUjYaflEyWqhOxOUh4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'This is so me ❤😂',
#   'Comment_Author': '@siidhraakiyaan4789',
#   'Comment_Published': '2024-01-25T17:31:47Z'},
#  {'Comment_id': 'UgxyRKjspBEHhXqBlgp4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'giving vibes  like great indian kitchen film story😂😂😂😂😂😂',
#   'Comment_Author': '@Assamese.Kalita',
#   'Comment_Published': '2024-01-25T17:24:14Z'},
#  {'Comment_id': 'UgzBGyV5Zs5iJM9gkQp4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'I am not jealous button',
#   'Comment_Author': '@MsGuitarist123',
#   'Comment_Published': '2024-01-25T17:23:13Z'},
#  {'Comment_id': 'Ugwdg3WNSxGIFPo9wv94AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Just married things😂',
#   'Comment_Author': '@nightingale2726',
#   'Comment_Published': '2024-01-25T17:22:38Z'},
#  {'Comment_id': 'UgyQeQXrCyn_smSs8BF4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Lovely couple. Aap donoko kiska nazar na lage',
#   'Comment_Author': '@gopalkrushnabehera2023',
#   'Comment_Published': '2024-01-25T17:20:43Z'},
#  {'Comment_id': 'UgwHlYjbNO3IOobjCmd4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': '😂😂😂',
#   'Comment_Author': '@omarfarouk1681',
#   'Comment_Published': '2024-01-25T17:19:38Z'},
#  {'Comment_id': 'UgypR4QvcocKYixKUit4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Pelam pilai on the way 😊😊😊',
#   'Comment_Author': '@sarthaksrivastava1563',
#   'Comment_Published': '2024-01-25T17:19:04Z'},
#  {'Comment_id': 'Ugxrhz1Idyp9rpF_pkx4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'God bless',
#   'Comment_Author': '@user-tv7ou8fi6r',
#   'Comment_Published': '2024-01-25T17:16:46Z'},
#  {'Comment_id': 'UgwwfGfXrN4KgKfJbtV4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Egg ache se boil nhi the😢',
#   'Comment_Author': '@Physicsclass12',
#   'Comment_Published': '2024-01-25T17:16:10Z'},
#  {'Comment_id': 'UgyvoH4dSjrpDjQGUXp4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Pakka arrange marriage',
#   'Comment_Author': '@santanuchakraborty1451',
#   'Comment_Published': '2024-01-25T17:14:12Z'},
#  {'Comment_id': 'UgxBI65pSfbbvatuxAV4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'lol 😂 Reel is not real 😂😂😂',
#   'Comment_Author': '@Luitporiya',
#   'Comment_Published': '2024-01-25T17:06:18Z'},
#  {'Comment_id': 'Ugy3o9UaKG7e94fIIml4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Chapri😂 chachi😂',
#   'Comment_Author': '@shwetakapoor7851',
#   'Comment_Published': '2024-01-25T17:04:18Z'},
#  {'Comment_id': 'UgyZ4IqSy_-agOEXyD14AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Gharwali ko naukrani bana diya???',
#   'Comment_Author': '@sukhvindersinghnagi9752',
#   'Comment_Published': '2024-01-25T16:52:59Z'},
#  {'Comment_id': 'UgzXrz1Dw9pb8Te1Mdt4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Besharmi',
#   'Comment_Author': '@NIGHTBIRD253',
#   'Comment_Published': '2024-01-25T16:51:38Z'},
#  {'Comment_id': 'UgxJCXmbGYPdfsHZYod4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Mashaallah',
#   'Comment_Author': '@syednoman2785',
#   'Comment_Published': '2024-01-25T16:51:08Z'},
#  {'Comment_id': 'Ugx8fQvXSKR8uMuAIZ14AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Maine to Pehle Dekh Kar Kajal Agarwal Samjha',
#   'Comment_Author': '@AbuRaihanPolok',
#   'Comment_Published': '2024-01-25T16:48:08Z'},
#  {'Comment_id': 'UgzAiyj9HtLJeXtKgFV4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Cringe Koodhinga da thaa 😂',
#   'Comment_Author': '@Voicerecorderprankaudio',
#   'Comment_Published': '2024-01-25T16:44:22Z'},
#  {'Comment_id': 'Ugw-qeHtRUCtkabe8rB4AaABAg',
#   'Video_id': '-m1gcRrXRKY',
#   'Comment_text': 'Song name?',
#   'Comment_Author': '@Abutaher-wx1vl',
#   'Comment_Published': '2024-01-25T16:39:29Z'},
#  {'Comment_id': 'UgxfvERP1Jz29a-w2mN4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Mom saree is much colorful than bride 😂',
#   'Comment_Author': '@ragavinjamuri',
#   'Comment_Published': '2024-01-25T18:24:04Z'},
#  {'Comment_id': 'UgwckVlhlYM6Zily70l4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Superb',
#   'Comment_Author': '@krishanughosh4353',
#   'Comment_Published': '2024-01-25T17:46:42Z'},
#  {'Comment_id': 'UgxL7kwKVsRG_c6-zKd4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Soo beautiful  ❤',
#   'Comment_Author': '@basavarajchipde3952',
#   'Comment_Published': '2024-01-25T11:10:51Z'},
#  {'Comment_id': 'UgwTZYGyS3K9fKmmClR4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Happy bhabhi ji',
#   'Comment_Author': '@prashantsingh3614',
#   'Comment_Published': '2024-01-25T09:00:48Z'},
#  {'Comment_id': 'UgxOwZOJX5dKuNIyki94AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'So traditional and Cultural Wow Di U look so gorgeous ❤ My Brother is so lucky he got u in his life as a charm ⭐️⭐️✨',
#   'Comment_Author': '@NATSU_04',
#   'Comment_Published': '2024-01-24T23:13:17Z'},
#  {'Comment_id': 'UgxA1XRc9gMsXHyZY214AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Onga Husband Unmailaiyea Kuduthu Vacha Varunga Onga La Marriage Pannathuku 😊❤️😌🔥💯',
#   'Comment_Author': '@iamthefutureofindia',
#   'Comment_Published': '2024-01-24T18:30:17Z'},
#  {'Comment_id': 'UgyzdrnojiSxibqcMlh4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Parvai fully in makeup where is your love',
#   'Comment_Author': '@kiran-dc7ps',
#   'Comment_Published': '2024-01-24T17:27:39Z'},
#  {'Comment_id': 'UgwknYREkwXU2rpYzcN4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Love you love💋💋💘💘',
#   'Comment_Author': '@ManojKumar-gj1gy',
#   'Comment_Published': '2024-01-23T12:51:15Z'},
#  {'Comment_id': 'UgyFgkmwV2jMi5ahTPZ4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'आपका गले का हार मुझे ज्यादा भारी लग रहा है, इससे मुझे दे दो । 😂',
#   'Comment_Author': '@AnmOl_ThakUr',
#   'Comment_Published': '2024-01-23T09:59:37Z'},
#  {'Comment_id': 'Ugy2tj9HAsmU6_mRILR4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Any time faver green 💚💚 saree 🎉🎉🎉',
#   'Comment_Author': '@jayakumar60',
#   'Comment_Published': '2024-01-23T08:02:19Z'},
#  {'Comment_id': 'UgxDA1hluqCOeApHT1l4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Why U r so soft 😅',
#   'Comment_Author': '@visiblle',
#   'Comment_Published': '2024-01-23T07:27:55Z'},
#  {'Comment_id': 'Ugw2jv0zLoVfM2QwWvR4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Doesn&#39;t understand the music but enjoy this!',
#   'Comment_Author': '@shivamsrivastava3350',
#   'Comment_Published': '2024-01-23T05:09:03Z'},
#  {'Comment_id': 'UgyBRo7-I62drph-K694AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Hi dear .. do we need EAD to make YouTube videos',
#   'Comment_Author': '@user-rt2iz7dq1j',
#   'Comment_Published': '2024-01-22T23:27:35Z'},
#  {'Comment_id': 'UgwUyncyoUT9NxKiie54AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Hello',
#   'Comment_Author': '@NiteshKumar-yd5mv',
#   'Comment_Published': '2024-01-22T18:16:43Z'},
#  {'Comment_id': 'UgySvef85sPOzOaarRx4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': '❤❤❤❤❤❤❤❤❤❤❤❤❤❤',
#   'Comment_Author': '@assammeghalaya5489',
#   'Comment_Published': '2024-01-22T17:48:19Z'},
#  {'Comment_id': 'UgxyqgSCB6Iu3b9dzqd4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Follow Dharma',
#   'Comment_Author': '@ProphetMohammad69',
#   'Comment_Published': '2024-01-22T12:21:34Z'},
#  {'Comment_id': 'UgyUYrBSLNDqJxVvVDF4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'How to contact u for colloboration?',
#   'Comment_Author': '@vvenkates1',
#   'Comment_Published': '2024-01-22T04:14:03Z'},
#  {'Comment_id': 'Ugxh_GEZPZXHjtDQbg14AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'ur jodi so so cute ,why cant u share ur love story to us❤and how ur marriage done in a video?',
#   'Comment_Author': '@varalakshmirathod3768',
#   'Comment_Published': '2024-01-21T20:02:13Z'},
#  {'Comment_id': 'UgwC3b4TB5z8tiO19a94AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Evlo alagu.. Namalam ipdi porakalaye',
#   'Comment_Author': '@user-ey5du3qy3f',
#   'Comment_Published': '2024-01-21T14:05:32Z'},
#  {'Comment_id': 'UgxZhcRlAPbFEbap2G14AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'so cute♥️♥️♥️♥️♥️👌',
#   'Comment_Author': '@anandvaidya8767',
#   'Comment_Published': '2024-01-21T09:44:49Z'},
#  {'Comment_id': 'UgwQ2qmNdKzEArHjd7N4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Bhabi Ji aapse binti hai ki AAP aisei rehna. Kuch likes aur share k liye please borderline nudity ko apnana maat.',
#   'Comment_Author': '@shreejitmitra7663',
#   'Comment_Published': '2024-01-21T07:47:23Z'},
#  {'Comment_id': 'UgxSRHKijDYeZ1b6rzN4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'How do you have such good hair, give some tips? Is it all just hereditary?!',
#   'Comment_Author': '@monikagiri9879',
#   'Comment_Published': '2024-01-19T12:26:53Z'},
#  {'Comment_id': 'UgyIOjG7eYDbPP00Bah4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Soo beautiful ❤️❤️',
#   'Comment_Author': '@Minalkashyap05',
#   'Comment_Published': '2024-01-19T03:31:49Z'},
#  {'Comment_id': 'UgwLcbSdIvH8BEqcLoV4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Hope I get married to My GF . She is cute too. But u r too much. 🎉',
#   'Comment_Author': '@mathematicsinbengali4911',
#   'Comment_Published': '2024-01-18T19:59:24Z'},
#  {'Comment_id': 'Ugwfjo2F--zY5GG7Iph4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Hi sis.. Are you a sourashtrian?',
#   'Comment_Author': '@yuvashreesomakanthan4342',
#   'Comment_Published': '2024-01-17T12:36:20Z'},
#  {'Comment_id': 'UgxfjlGryScIMBDoD894AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': '😊😊😊😊',
#   'Comment_Author': '@gokulkrishnaklbro917',
#   'Comment_Published': '2024-01-17T07:18:58Z'},
#  {'Comment_id': 'Ugy2QSQQjXXGyTEfIQR4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Rasagula ❤❤❤',
#   'Comment_Author': '@ammurohini2337',
#   'Comment_Published': '2024-01-14T10:29:36Z'},
#  {'Comment_id': 'UgzpvM2IfAjVOeizJQ54AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'awieeee cutieee 😘🥰🤩',
#   'Comment_Author': '@nithyaharini.j.p8173',
#   'Comment_Published': '2024-01-10T13:58:19Z'},
#  {'Comment_id': 'UgzHSQe3MoaDfjMyWGV4AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Cupcake 🎈',
#   'Comment_Author': '@sakthisusi3513',
#   'Comment_Published': '2024-01-10T05:14:01Z'},
#  {'Comment_id': 'Ugx2ZH0QfhnqYK87Og14AaABAg',
#   'Video_id': '1j63n_6lkhM',
#   'Comment_text': 'Angel living in earth 💗😌',
#   'Comment_Author': '@Priyanka_.3',
#   'Comment_Published': '2024-01-09T23:26:06Z'},
#  {'Comment_id': 'UgweMl39N0l7MZsar7F4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'can u tell me about that rosemary&amp;mint hair oil?',
#   'Comment_Author': '@lakshmipriya5564',
#   'Comment_Published': '2024-01-27T12:43:25Z'},
#  {'Comment_id': 'UgxHfLdILdYUC-dXTeJ4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'Can u start making the videos in hindi plz 🥹🥹🥹',
#   'Comment_Author': '@ffgameryt3183',
#   'Comment_Published': '2024-01-25T12:51:54Z'},
#  {'Comment_id': 'UgxCS-_6G-WnEXpXkIl4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'Banana can do eny thing<br>What a banana <br>It was lucky',
#   'Comment_Author': '@kiran-dc7ps',
#   'Comment_Published': '2024-01-24T17:29:23Z'},
#  {'Comment_id': 'UgxdxCm3msj1OMMLIZB4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'Pls di make vlog in hindi 😊',
#   'Comment_Author': '@Taznim-Mohib',
#   'Comment_Published': '2024-01-21T09:08:30Z'},
#  {'Comment_id': 'Ugz9lKEPRJV8593RBLR4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'Pls make ur videos in Hindi version',
#   'Comment_Author': '@manishashroff7754',
#   'Comment_Published': '2024-01-21T06:06:05Z'},
#  {'Comment_id': 'Ugylv3FahZNau5hMQOV4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'Lucky Husband ❤❤',
#   'Comment_Author': '@Raju-po5uu',
#   'Comment_Published': '2024-01-20T10:24:40Z'},
#  {'Comment_id': 'Ugx5gmNEdDvMYTyXqId4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'Kuch samaj nehi aya 😅',
#   'Comment_Author': '@5gworld13',
#   'Comment_Published': '2024-01-19T21:11:32Z'},
#  {'Comment_id': 'UgypiQs6_2YgAL_3rRB4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'illa samjha kuch 😢😢😢',
#   'Comment_Author': '@ImmatureBaller8010',
#   'Comment_Published': '2024-01-19T10:49:13Z'},
#  {'Comment_id': 'UgxY521_zwfgn-W3e3F4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'Outfit from',
#   'Comment_Author': '@sancharimandal4035',
#   'Comment_Published': '2024-01-13T11:46:35Z'},
#  {'Comment_id': 'Ugx9L61LbszX2_IQgtd4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'Share your skincare routine , and tell us about that nalangu maavu ka❤️',
#   'Comment_Author': '@harinivedhaselvam7826',
#   'Comment_Published': '2024-01-04T13:20:39Z'},
#  {'Comment_id': 'UgxxqVz-bpyXP2s-iux4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'Awww always giving a positive vibe wid ur smile 💗',
#   'Comment_Author': '@Priyanka_.3',
#   'Comment_Published': '2024-01-04T11:59:51Z'},
#  {'Comment_id': 'UgxlYMT2kSWaknvhUU94AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'Sis we need a usual vlog please and home tour,some other information about your love story',
#   'Comment_Author': '@kowsinayak7240',
#   'Comment_Published': '2024-01-04T05:06:39Z'},
#  {'Comment_id': 'UgzeRUmehoadJUwgsmN4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': '😍😍❤️',
#   'Comment_Author': '@Shilfy2000',
#   'Comment_Published': '2024-01-04T04:07:34Z'},
#  {'Comment_id': 'Ugxn4ueJYAyVq_2tHYR4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'Both of u lokking like a wow',
#   'Comment_Author': '@anshumanvats6366',
#   'Comment_Published': '2024-01-04T03:39:29Z'},
#  {'Comment_id': 'Ugw9Lvwt5zF96rVXnsl4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'Kutty vlog  Just looking like a Wow✨',
#   'Comment_Author': '@sakthisusi3513',
#   'Comment_Published': '2024-01-04T02:36:24Z'},
#  {'Comment_id': 'UgxdB6_tBRuk64Di1rV4AaABAg',
#   'Video_id': 'Iyo6bDWrOLw',
#   'Comment_text': 'U look pretty ka😍',
#   'Comment_Author': '@Mathu_Kowshi',
#   'Comment_Published': '2024-01-04T00:46:40Z'},
#  {'Comment_id': 'Ugxqvw492UStk3k9oZh4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'i love ur tradition',
#   'Comment_Author': '@jayalakshmiab9906',
#   'Comment_Published': '2024-01-27T04:46:03Z'},
#  {'Comment_id': 'UgyMw8QA1INVurCU-xB4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Didi can you please make your video in hindi or english <br>I love your videos 💖 but can&#39;t understand 💔',
#   'Comment_Author': '@aparannharoy6697',
#   'Comment_Published': '2024-01-25T09:44:35Z'},
#  {'Comment_id': 'UgxmPUnZy5G_gqfeDm54AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Congratulations 🎉',
#   'Comment_Author': '@aparannharoy6697',
#   'Comment_Published': '2024-01-25T09:42:45Z'},
#  {'Comment_id': 'Ugwf6ICI2u9nX3ckXhh4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Banana can do eny thing<br>Its very lucky',
#   'Comment_Author': '@kiran-dc7ps',
#   'Comment_Published': '2024-01-24T17:31:25Z'},
#  {'Comment_id': 'UgzgMT1sYyOG7oKB_YN4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Congratulations 👏🎉',
#   'Comment_Author': '@safimohammad8412',
#   'Comment_Published': '2024-01-24T12:02:52Z'},
#  {'Comment_id': 'UgxiPSt8pMzZtcASEyF4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Ur Treditional Looks So So So Awesome 👌👌❤️',
#   'Comment_Author': '@nravalrraval83',
#   'Comment_Published': '2024-01-22T19:25:54Z'},
#  {'Comment_id': 'UgwPLkN8KPhE8h_Ht-h4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Azhaku❤. Maam love from kerala',
#   'Comment_Author': '@jinumanchira',
#   'Comment_Published': '2024-01-22T16:47:42Z'},
#  {'Comment_id': 'Ugxqcz8M_namvX-52e54AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Linga bhairavi🎉',
#   'Comment_Author': '@Krishnagrace111',
#   'Comment_Published': '2024-01-22T07:30:15Z'},
#  {'Comment_id': 'UgzQcTof6oQ-tVtYakN4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'I don&#39;t understand but I like u',
#   'Comment_Author': '@dhaliwaldhaliwal8347',
#   'Comment_Published': '2024-01-22T06:58:28Z'},
#  {'Comment_id': 'UgywQAVpAdyQT6Ykr_J4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Congratulations 🏡',
#   'Comment_Author': '@chinUnboxing',
#   'Comment_Published': '2024-01-22T03:45:56Z'},
#  {'Comment_id': 'Ugxmxr6eZQuqVR5KwSV4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'I love watching your videos <br>But  I can&#39;t understand your language.  Where are you from sister? I am from lucknow u.p.',
#   'Comment_Author': '@AmirKhan-xq2en',
#   'Comment_Published': '2024-01-22T00:35:11Z'},
#  {'Comment_id': 'UgxjDsZjpmJvktgaw_B4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Elleee no south  language  😅<br>English  will  understand everyone',
#   'Comment_Author': '@vijaybagad9890',
#   'Comment_Published': '2024-01-21T20:38:18Z'},
#  {'Comment_id': 'UgwYxP-egMhx-_XK-A94AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Which city n state in US',
#   'Comment_Author': '@lemont9061',
#   'Comment_Published': '2024-01-21T19:08:31Z'},
#  {'Comment_id': 'UgxgyFR0jEBxJLFYqMN4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Safe ஆ இருங்க... தினம் தினம் மெதுவாக வீட்டை set செய்ங்க... 👍',
#   'Comment_Author': '@srinivasansujatha2757',
#   'Comment_Published': '2024-01-21T16:23:34Z'},
#  {'Comment_id': 'Ugxxe_jcx35Vll7g2Gh4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Pretty in saree🌸🧿',
#   'Comment_Author': '@adi_official93',
#   'Comment_Published': '2024-01-21T11:56:17Z'},
#  {'Comment_id': 'UgzFuXGMZ9pWt2HVV7R4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Ur snap chat id plss',
#   'Comment_Author': '@harijanasravanthi1514',
#   'Comment_Published': '2024-01-21T11:34:25Z'},
#  {'Comment_id': 'UgyDqx94VBiER2u9MUB4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Where is your parents',
#   'Comment_Author': '@behappy7439',
#   'Comment_Published': '2024-01-20T20:56:38Z'},
#  {'Comment_id': 'UgxaiDTSYQO8xSuvF614AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'I hate your g',
#   'Comment_Author': '@syamprasad8840',
#   'Comment_Published': '2024-01-20T15:56:17Z'},
#  {'Comment_id': 'Ugx4N3OjVW098tZ0FQV4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Ena tamil pesringa...neenga North Indian ilaya',
#   'Comment_Author': '@maxver760',
#   'Comment_Published': '2024-01-17T19:51:08Z'},
#  {'Comment_id': 'UgzJPR_Rua2pAB-qseN4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Aaah🤩 your blouse and saree link please😢',
#   'Comment_Author': '@Sindhu-xm8fr',
#   'Comment_Published': '2024-01-15T08:45:25Z'},
#  {'Comment_id': 'Ugyjd4Bh3drKBWyyVMR4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Pls upload  ur love story and more video',
#   'Comment_Author': '@kanagarajs800',
#   'Comment_Published': '2023-12-27T13:10:33Z'},
#  {'Comment_id': 'Ugy6XRaHNpCUScuR11t4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Full vlogs podunga ka vlogs pathu romba days achu ❤️ From Chennai 🫶🏻',
#   'Comment_Author': '@bakiyakumar5277',
#   'Comment_Published': '2023-12-24T10:57:02Z'},
#  {'Comment_id': 'Ugz3IqmeHVH_aUCqqMp4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Akka ungaloda hairstyle video podunga',
#   'Comment_Author': '@JothiJothi-np3um',
#   'Comment_Published': '2023-12-23T13:40:09Z'},
#  {'Comment_id': 'UgwCyhjN-4wVM3KEO2h4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Feeling excited when my phone notifies me that u posted the vlog 😌💗',
#   'Comment_Author': '@Priyanka_.3',
#   'Comment_Published': '2023-12-23T12:38:45Z'},
#  {'Comment_id': 'Ugw-aukRiA-kRcOcUQJ4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Neega Isha family ah',
#   'Comment_Author': '@EzhilRavi-tc4mf',
#   'Comment_Published': '2023-12-23T08:25:05Z'},
#  {'Comment_id': 'Ugw_Li6rGiMZp-Gfg994AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Loving the vlogs, want YouTube videos tooo pleaseeeee ❤',
#   'Comment_Author': '@udayaaasritha9053',
#   'Comment_Published': '2023-12-23T05:39:06Z'},
#  {'Comment_id': 'UgxbGPKELg9Ml690X9p4AaABAg',
#   'Video_id': '8AYX7LjjoyI',
#   'Comment_text': 'Do long vlogs dear❤..... Happy for you❤',
#   'Comment_Author': '@janvlogs_06',
#   'Comment_Published': '2023-12-23T05:32:13Z'},
#  {'Comment_id': 'Ugx4FT7J7eVjefBSYG54AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
#   'Comment_text': 'nice video😮😮',
#   'Comment_Author': '@tarifboyvideo',
#   'Comment_Published': '2024-01-25T15:50:11Z'},
#  {'Comment_id': 'UgwWXVRmQ_bs2ty6sU94AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
#   'Comment_text': '❤❤❤❤',
#   'Comment_Author': '@user-ju6uy6cp5f',
#   'Comment_Published': '2024-01-25T12:59:39Z'},
#  {'Comment_id': 'UgwrIeMZsD2cUaSuNjJ4AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
#   'Comment_text': 'Hey bhabhi ji hindi to bola kijye ji',
#   'Comment_Author': '@prashantsingh3614',
#   'Comment_Published': '2024-01-25T09:01:46Z'},
#  {'Comment_id': 'UgzOSgouIw-TKsn4wVN4AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
#   'Comment_text': 'Ho❤',
#   'Comment_Author': '@user-nu6pe5fr3u',
#   'Comment_Published': '2024-01-25T08:58:08Z'},
#  {'Comment_id': 'UgyKL5R_gtmbqZcKrFF4AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
#   'Comment_text': 'beautiful❤️💕💕❤️',
#   'Comment_Author': '@mohammadmursaleen3918',
#   'Comment_Published': '2024-01-25T07:53:50Z'},
#  {'Comment_id': 'UgzEY_P3Dv_We2u-tQp4AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
#   'Comment_text': 'Can&#39;t understand bt it felt very nice ❤❤',
#   'Comment_Author': '@bababhartimotivation',
#   'Comment_Published': '2024-01-24T16:53:51Z'},
#  {'Comment_id': 'Ugw3mmIRUQHpSq4Wob14AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
#   'Comment_text': 'Beautiful girl ❤️❤️❤️❤️❤️❤️',
#   'Comment_Author': '@mahevini9372',
#   'Comment_Published': '2024-01-24T07:37:12Z'},
#  {'Comment_id': 'UgwqHsLqjyE6AVQEB194AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
#   'Comment_text': 'While You looking so beautiful but also look like Goddess Annapurna.. 👌🏻👌🏻',
#   'Comment_Author': '@theironmanavenger89',
#   'Comment_Published': '2024-01-23T19:23:58Z'},
#  {'Comment_id': 'UgyEEPTB7h_9IDBSja54AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
#   'Comment_text': '❤',
#   'Comment_Author': '@user-no5pf9dm7p',
#   'Comment_Published': '2024-01-23T16:10:51Z'},
#  {'Comment_id': 'UgwrlOdMti55otP8lAB4AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
#   'Comment_text': 'Please, speak in English or Hindi !!!!',
#   'Comment_Author': '@-ve5fk',
#   'Comment_Published': '2024-01-23T08:46:14Z'},
#  {'Comment_id': 'UgxiPpC9x6yFhDjzuVF4AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
#   'Comment_text': 'Beautyful ❤',
#   'Comment_Author': '@nittalsahani5563',
#   'Comment_Published': '2024-01-23T01:22:02Z'},
#  {'Comment_id': 'UgxtxE_9Ct9nfGskx5F4AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
#   'Comment_text': 'your face..very quite🎉',
#   'Comment_Author': '@vickeymalhotra857',
#   'Comment_Published': '2024-01-21T11:06:43Z'},
#  {'Comment_id': 'UgxEZ-jR7IEJ-JrFO0h4AaABAg',
#   'Video_id': '_QiSqY0Mi5k',
# ...
#   'Comment_Author': '@ammurohini2337',
#   'Comment_Published': '2023-10-30T11:34:12Z'},
#  {'Comment_id': 'UgylohstQ2ACiIJaCC54AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Just loved your videos beii❤',
#   'Comment_Author': '@sujithasujitha7928',
#   'Comment_Published': '2023-09-23T14:01:01Z'},
#  {'Comment_id': 'UgzhnMR9LVW_Occw5rF4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'So beautiful ❤️❤️❤️ just loving your recently and absolutely amazing 😍 you are spreading so much positivity and love 💕<br>A small request there are fans for you from other states as well so could u add subtitles your love story video pleaseeeeeeee<br>Stay happy you guys, take care and sending lots of loveeeee 🫶❤️',
#   'Comment_Author': '@udayaaasritha9053',
#   'Comment_Published': '2023-06-12T12:59:17Z'},
#  {'Comment_id': 'UgwcZL_SiQBa0830mzl4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Love from SriLanka ❤️',
#   'Comment_Author': '@kulentheranathanbavatharan1890',
#   'Comment_Published': '2023-04-01T08:10:47Z'},
#  {'Comment_id': 'UgzMpKtIl10AiAvFni54AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'I randomly got this video on my recommends as I love watching diml vlogs n stuff , and I think you should upload more it&#39;s cute to watch 💗',
#   'Comment_Author': '@sarahsebastine1692',
#   'Comment_Published': '2023-03-31T08:14:09Z'},
#  {'Comment_id': 'UgwI62YfWVoaRHSk4IJ4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Loved this 😍I enjoyed this so much❤️',
#   'Comment_Author': '@Online_quranclass_for_ladies',
#   'Comment_Published': '2023-03-28T08:33:49Z'},
#  {'Comment_id': 'Ugy5To17cp7VwPA4yL94AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Very nice vlog❤ keep doing more☺️',
#   'Comment_Author': '@akshayaseetharaman5687',
#   'Comment_Published': '2023-03-27T11:57:18Z'},
#  {'Comment_id': 'Ugwc3fjAWo-vIA7orRd4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Loved for vlog…Continue to do more videos ❤️',
#   'Comment_Author': '@sruthimuthuvelu9010',
#   'Comment_Published': '2023-03-27T11:42:04Z'},
#  {'Comment_id': 'UgwT9abhGYsYxDkBXCB4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Always gorgeous 😍🥰 .. waiting for more videos big one .. lots of love to you ❤️ 😘',
#   'Comment_Author': '@anushadevi1115',
#   'Comment_Published': '2023-03-27T07:53:54Z'},
#  {'Comment_id': 'UgwfGzpu1HigdZ1nYJV4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Loved this vlog Baby😍❤️ Spread Happiness ❤️❤️',
#   'Comment_Author': '@Shilfy2000',
#   'Comment_Published': '2023-03-26T19:00:31Z'},
#  {'Comment_id': 'UgxijD6BFT6tvtxkMfV4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Loved watching your day to day life routine.. And do share whatever you feel to share da 😊✨looking forward to see more content 💙more love to you 🤗',
#   'Comment_Author': '@riyamakeupandstyling',
#   'Comment_Published': '2023-03-26T18:54:49Z'},
#  {'Comment_id': 'UgzWXxUxPlXrq28Ugex4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Keep Posting  more  &amp;  more videos mai 😍😍😍',
#   'Comment_Author': '@sharmilarani7095',
#   'Comment_Published': '2023-03-26T16:11:22Z'},
#  {'Comment_id': 'UgykGuzT3Nzy4kqnFU54AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Nice vlog ❤❤❤ waiting for more nd more videos alagi❤',
#   'Comment_Author': '@subhalakshmanan4326',
#   'Comment_Published': '2023-03-26T16:11:01Z'},
#  {'Comment_id': 'Ugy5hY4KuAsRqRcozUZ4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Loved the outdoor part and oli part, and the night routine part. Excited for more outdoor vlogs like gym, theppakulam, oli walking, sundaram park 🎉',
#   'Comment_Author': '@kedharguhan',
#   'Comment_Published': '2023-03-26T15:58:48Z'},
#  {'Comment_id': 'UgxfnO305D9ZHJbARgl4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Welldone kuttyma. Happy to c u growing💗 nd so happy to c ur videos da keep posting more dear much love from ur fan cum sis☺️',
#   'Comment_Author': '@yaami_krish',
#   'Comment_Published': '2023-03-26T15:16:24Z'},
#  {'Comment_id': 'UgwqYED0OPxicBJSK0N4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Hi bei neega enna paduchiga',
#   'Comment_Author': '@varshakannan5596',
#   'Comment_Published': '2023-03-26T14:44:03Z'},
#  {'Comment_id': 'UgzQpSoD6TCyJ9cEzFx4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Hello 😊',
#   'Comment_Author': '@BeStrongArmwrestling',
#   'Comment_Published': '2023-03-26T14:40:49Z'},
#  {'Comment_id': 'Ugw0-NbLQLvxtdOZ8Dp4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Way more to go Babess❤️',
#   'Comment_Author': '@getzianissi1603',
#   'Comment_Published': '2023-03-26T14:19:55Z'},
#  {'Comment_id': 'UgwydpB2_UpxpiSvHOp4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Voice is low da try to improve other than doing gooooddddd❤❤❤❤',
#   'Comment_Author': '@devipriya6485',
#   'Comment_Published': '2023-03-26T14:14:05Z'},
#  {'Comment_id': 'Ugx_s58rp_VcKzdRcRl4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Woww❤😍 waiting for more videos❤',
#   'Comment_Author': '@nithyaharini.j.p8173',
#   'Comment_Published': '2023-03-26T14:05:17Z'},
#  {'Comment_id': 'UgyXVAfFlIhJ7Xx_Z594AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': '❤',
#   'Comment_Author': '@subhikshalenin6046',
#   'Comment_Published': '2023-03-26T13:50:27Z'},
#  {'Comment_id': 'Ugzy-jzJ_VdZ8IrLRaB4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Hii bei',
#   'Comment_Author': '@kannansabitha992',
#   'Comment_Published': '2023-03-26T13:48:46Z'},
#  {'Comment_id': 'Ugx5v361y6iDjrQ5xOh4AaABAg',
#   'Video_id': 'pv2vzRWg3Ac',
#   'Comment_text': 'Odi vanthachuuu🎉',
#   'Comment_Author': '@jananid3619',
#   'Comment_Published': '2023-03-26T13:47:50Z'},
#  {'Comment_id': 'UgwAN451zMuTxssjXHl4AaABAg',
#   'Video_id': 'urbS57f9ZxU',
#   'Comment_text': 'Skirt link',
#   'Comment_Author': '@amangartia3953',
#   'Comment_Published': '2024-01-25T14:53:17Z'},
#  {'Comment_id': 'Ugy9vFFBu-2UHOHcODR4AaABAg',
#   'Video_id': 'urbS57f9ZxU',
#   'Comment_text': 'Really nv same alane unnav andanga',
#   'Comment_Author': '@kittukutty4275',
#   'Comment_Published': '2024-01-19T11:03:47Z'},
#  {'Comment_id': 'Ugyi0Ce6qNz4NVS-gAJ4AaABAg',
#   'Video_id': 'urbS57f9ZxU',
#   'Comment_text': 'beautiful ❤❤',
#   'Comment_Author': '@manojfighter6754',
#   'Comment_Published': '2024-01-19T06:57:08Z'},
#  {'Comment_id': 'UgzKQnKKMnmd8CUWHNh4AaABAg',
#   'Video_id': 'urbS57f9ZxU',
#   'Comment_text': 'Sweet ❤❤',
#   'Comment_Author': '@user-gz8kq1dw9m',
#   'Comment_Published': '2023-05-28T08:13:17Z'},
#  {'Comment_id': 'UgxIYXJG3571YmH5DwZ4AaABAg',
#   'Video_id': 'urbS57f9ZxU',
#   'Comment_text': 'superstar',
#   'Comment_Author': '@BeStrongArmwrestling',
#   'Comment_Published': '2023-03-24T03:11:52Z'},
#  {'Comment_id': 'UgwDgYH-YerBfiheudZ4AaABAg',
#   'Video_id': 'urbS57f9ZxU',
#   'Comment_text': 'Cutieee ❤',
#   'Comment_Author': '@nithyaharini.j.p8173',
#   'Comment_Published': '2023-03-23T16:48:36Z'},
#  {'Comment_id': 'UgywCKBp00XIZHEELOx4AaABAg',
#   'Video_id': 'urbS57f9ZxU',
#   'Comment_text': '💃',
#   'Comment_Author': '@kedharguhan',
#   'Comment_Published': '2023-03-23T15:51:25Z'},
#  {'Comment_id': 'Ugwelq2ow1Harajkd3N4AaABAg',
#   'Video_id': 'urbS57f9ZxU',
#   'Comment_text': '😍😍❤️',
#   'Comment_Author': '@Shilfy2000',
#   'Comment_Published': '2023-03-23T15:19:05Z'},
#  {'Comment_id': 'Ugy4i1PB5DS0-OGNXp54AaABAg',
#   'Video_id': 'n1l7Iyznfvg',
#   'Comment_text': 'So cute 🎉❤🎉❤',
#   'Comment_Author': '@rajaduraitnfrs9595',
#   'Comment_Published': '2024-01-25T08:17:39Z'},
#  {'Comment_id': 'UgxHdw9UZ12jFDPHSiV4AaABAg',
#   'Video_id': 'n1l7Iyznfvg',
#   'Comment_text': 'Fan from. Kerala❤',
#   'Comment_Author': '@jinumanchira',
#   'Comment_Published': '2024-01-22T16:51:43Z'},
#  {'Comment_id': 'UgwNqKB84LohVNIVxVR4AaABAg',
#   'Video_id': 'n1l7Iyznfvg',
#   'Comment_text': 'Cute',
#   'Comment_Author': '@sakthisusi3513',
#   'Comment_Published': '2023-12-28T06:21:07Z'},
#  {'Comment_id': 'UgwGJm3pmEEPRn-gGNh4AaABAg',
#   'Video_id': 'n1l7Iyznfvg',
#   'Comment_text': 'Cute mil n Dil ❤️',
#   'Comment_Author': '@n4nupra',
#   'Comment_Published': '2023-03-24T13:08:24Z'},
#  {'Comment_id': 'UgwXFj3xeLncZW6ponJ4AaABAg',
#   'Video_id': 'n1l7Iyznfvg',
#   'Comment_text': 'My beautiful baby 😍',
#   'Comment_Author': '@Shilfy2000',
#   'Comment_Published': '2023-03-22T18:38:08Z'},
#  {'Comment_id': 'Ugz0gCPHDjprAFcB8gJ4AaABAg',
#   'Video_id': 'Zy_rQcpZMEA',
#   'Comment_text': 'You are looking very beautiful',
#   'Comment_Author': '@krishanughosh4353',
#   'Comment_Published': '2024-01-25T17:39:29Z'},
#  {'Comment_id': 'UgwMQSX0cJE5VpDl6v54AaABAg',
#   'Video_id': 'Zy_rQcpZMEA',
#   'Comment_text': 'Gorgeous ❤❤❤',
#   'Comment_Author': '@jinumanchira',
#   'Comment_Published': '2024-01-22T16:51:26Z'},
#  {'Comment_id': 'UgxNRzPpmDLSKf7f-Ht4AaABAg',
#   'Video_id': 'Zy_rQcpZMEA',
#   'Comment_text': 'உங்களுக்கு எல்லா வகையான ட்ரெஸ்சஸ்சும் நன்றாகவே பொருந்துகிறது',
#   'Comment_Author': '@srinivasansujatha2757',
#   'Comment_Published': '2024-01-21T16:29:11Z'},
#  {'Comment_id': 'Ugz74oajf_PE_Je997p4AaABAg',
#   'Video_id': 'Zy_rQcpZMEA',
#   'Comment_text': 'So beautiful dresses 😍',
#   'Comment_Author': '@nikitafernandes461',
#   'Comment_Published': '2024-01-20T15:00:59Z'},
#  {'Comment_id': 'UgzJMn66fSjVhZpvBg54AaABAg',
#   'Video_id': 'Zy_rQcpZMEA',
#   'Comment_text': 'Akka ✨ Your videos are awesome <br>Keep doing ❤ enaku tamil teriyadhu but for you I&#39;m learning ,  ninga videos romba nalla irruku 👌🥰',
#   'Comment_Author': '@AmmaNannaKitchen',
#   'Comment_Published': '2024-01-18T05:17:43Z'},
#  {'Comment_id': 'UgxkphjeV9iw8szxYvB4AaABAg',
#   'Video_id': 'Zy_rQcpZMEA',
#   'Comment_text': 'Were u buy all these dresses',
#   'Comment_Author': '@keerthanarajagopal2617',
#   'Comment_Published': '2024-01-14T12:11:45Z'},
#  {'Comment_id': 'Ugyt5ffRutYK5G2eLft4AaABAg',
#   'Video_id': 'Zy_rQcpZMEA',
#   'Comment_text': 'Stylish ☺️',
#   'Comment_Author': '@n4nupra',
#   'Comment_Published': '2023-03-24T13:08:45Z'},
#  {'Comment_id': 'UgyswqR45EhxJCFyzoF4AaABAg',
#   'Video_id': 'Zy_rQcpZMEA',
#   'Comment_text': '😍😍😍😍',
#   'Comment_Author': '@Shilfy2000',
#   'Comment_Published': '2023-03-21T03:37:16Z'},
#  {'Comment_id': 'UgxOWHfa_LyiYMhCuMt4AaABAg',
#   'Video_id': 'Zy_rQcpZMEA',
#   'Comment_text': 'Adhiradi dhaan 🔥',
#   'Comment_Author': '@kedharguhan',
#   'Comment_Published': '2023-03-20T19:57:07Z'},
#  {'Comment_id': 'Ugw-jsPF2LYz5iz2HNh4AaABAg',
#   'Video_id': 'Zy_rQcpZMEA',
#   'Comment_text': 'Styluuuu 🔥🔥',
#   'Comment_Author': '@nithyaharini.j.p8173',
#   'Comment_Published': '2023-03-20T12:24:34Z'},
#  {'Comment_id': 'UgyIEYcKRl386L4DENt4AaABAg',
#   'Video_id': 'Zy_rQcpZMEA',
#   'Comment_text': 'Cute cute🎉❤',
#   'Comment_Author': '@jananid3619',
#   'Comment_Published': '2023-03-20T11:34:49Z'},
#  {'Comment_id': 'UgzCMCtCtX4NikPTxE94AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Hindi बोला karo',
#   'Comment_Author': '@rameshvlog2793',
#   'Comment_Published': '2024-01-25T16:16:49Z'},
#  {'Comment_id': 'UgxCbANQIeleBbneSSl4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Very informative video, want to know if it caused any redness in eyes after surgery!!',
#   'Comment_Author': '@mahasriswethak.r.4355',
#   'Comment_Published': '2023-04-17T14:36:42Z'},
#  {'Comment_id': 'UgwoqONVthli7L2bYpN4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Very useful information.👌👏👏💐',
#   'Comment_Author': '@aarthiravichand737',
#   'Comment_Published': '2023-04-09T18:09:09Z'},
#  {'Comment_id': 'UgzENzMVzurOdI-0fJR4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Very nice and exhaustive. Keep it up 👍',
#   'Comment_Author': '@balakumarthirukonda3011',
#   'Comment_Published': '2023-03-22T13:50:53Z'},
#  {'Comment_id': 'Ugx4DbG8KUZoYLzMCQV4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': '<a href="UCkszU2WH9gy1mb0dV-11UJg/hm5IY4W-H9SO5QS6n4CwCA"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/hm5IY4W-H9SO5QS6n4CwCA"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/hm5IY4W-H9SO5QS6n4CwCA"></a>',
#   'Comment_Author': '@BeStrongArmwrestling',
#   'Comment_Published': '2023-03-21T21:26:38Z'},
#  {'Comment_id': 'UgyJj7vqojbd-eYC-UF4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Great explanation ❤️💯',
#   'Comment_Author': '@subhikshalenin6046',
#   'Comment_Published': '2023-03-19T11:48:43Z'},
#  {'Comment_id': 'Ugy9DITh7QBRQoLTXox4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Crystal clear explanation more the way to go. Wish u all success dear💐🎉💯',
#   'Comment_Author': '@yaami_krish',
#   'Comment_Published': '2023-03-19T07:19:52Z'},
#  {'Comment_id': 'UgzKzAc9yrs_qj3uLm54AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Thank u for this informative video❤.. Much needed one 😇',
#   'Comment_Author': '@Priya-cf1cy',
#   'Comment_Published': '2023-03-19T07:04:02Z'},
#  {'Comment_id': 'UgxvNmqqXD5lHYJa0op4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Love how you explained everything in detail✨look like this is not your first video coz you explained and spoke clearly glad you made a voice through video . More to come here 😊and subscribed❤️',
#   'Comment_Author': '@riyamakeupandstyling',
#   'Comment_Published': '2023-03-18T15:21:52Z'},
#  {'Comment_id': 'UgwDAOnTG_xO9FQWSEx4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Wow akka very informative and useful .... More to gooo akka 🤩🔥.. great beginning',
#   'Comment_Author': '@anushadevi1115',
#   'Comment_Published': '2023-03-18T12:00:02Z'},
#  {'Comment_id': 'UgxR9qGutj11elN5mrJ4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': '❤❤❤❤❤way to go baby',
#   'Comment_Author': '@devipriya6485',
#   'Comment_Published': '2023-03-18T10:22:46Z'},
#  {'Comment_id': 'Ugy9U-02mfSKTb6H4mF4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Wow super akka <br>Keep rocking 🎉 waiting for more videos 🥳🥳',
#   'Comment_Author': '@nithyaharini.j.p8173',
#   'Comment_Published': '2023-03-18T10:09:40Z'},
#  {'Comment_id': 'UgxTTDMyKiGhmBUHjp14AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Way more to go Baby ❤️😍',
#   'Comment_Author': '@Shilfy2000',
#   'Comment_Published': '2023-03-18T07:48:18Z'},
#  {'Comment_id': 'UgyrJO3UD3wNqUtS5894AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Wow !!!  I am so thankful that God made U my daughter 😍😍😍',
#   'Comment_Author': '@sharmilarani7095',
#   'Comment_Published': '2023-03-18T07:12:18Z'},
#  {'Comment_id': 'UgzTBRVJDXQCY3MQDyB4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Glad to see your long format videos mu',
#   'Comment_Author': '@kedharguhan',
#   'Comment_Published': '2023-03-18T06:55:29Z'},
#  {'Comment_id': 'UgyAt8HlQQCRMVm0SUp4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': '🎉🎉🎉',
#   'Comment_Author': '@kedharguhan',
#   'Comment_Published': '2023-03-18T06:53:26Z'},
#  {'Comment_id': 'Ugw-f4mwGe4vlKnR1vF4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'YOUR GROWING AND AM CRYINGGG🥺💯',
#   'Comment_Author': '@harshithashree3033',
#   'Comment_Published': '2023-03-18T06:44:40Z'},
#  {'Comment_id': 'UgzOa6Vfi_rmJ5wn6Lh4AaABAg',
#   'Video_id': 'J2bczj1A-W4',
#   'Comment_text': 'Uthara❤',
#   'Comment_Author': '@subhalakshmanan4326',
#   'Comment_Published': '2023-03-18T06:29:49Z'},
#  {'Comment_id': 'UgybOYLJWotybpi-OW14AaABAg',
#   'Video_id': 'Ar_RvdaZ-7w',
#   'Comment_text': 'Nice ❤',
#   'Comment_Author': '@sathishp3987',
#   'Comment_Published': '2024-01-20T11:15:11Z'},
#  {'Comment_id': 'Ugz5b0AwTgPNKVFS_ZF4AaABAg',
#   'Video_id': 'Ar_RvdaZ-7w',
#   'Comment_text': 'U look like rihaana',
#   'Comment_Author': '@akshitathakur6124',
#   'Comment_Published': '2024-01-19T18:19:22Z'},
#  {'Comment_id': 'UgxYRfbBJMAE6VUSbzZ4AaABAg',
#   'Video_id': 'Ar_RvdaZ-7w',
#   'Comment_text': 'Hi Uthra Happy to see that you are doing great! I&#39;m Amirtha from school ❤',
#   'Comment_Author': '@amirthasenthilkumar4575',
#   'Comment_Published': '2024-01-17T13:49:31Z'},
#  {'Comment_id': 'Ugw_bsVSWwwzNsGQPsp4AaABAg',
#   'Video_id': 'Ar_RvdaZ-7w',
#   'Comment_text': 'Lipstick shade pls 🙏',
#   'Comment_Author': '@rasmiyahraspberry6335',
#   'Comment_Published': '2024-01-15T07:10:12Z'},
#  {'Comment_id': 'UgyTffJo_cMJWrpVsKZ4AaABAg',
#   'Video_id': 'Ar_RvdaZ-7w',
#   'Comment_text': 'What a changeover mame',
#   'Comment_Author': '@kedharguhan',
#   'Comment_Published': '2022-02-17T06:13:53Z'}]

# %%
def get_playlist_details(youtube, channel_id):
    next_page_token = None
    All_data = []
    while True:
        request = youtube.playlists().list(
            part='snippet,contentDetails',
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token
        )
        response = request.execute()

        for item in response['items']:
            data = {
                'Playlist_Id': item['id'],
                'Title': item['snippet']['title'],
                'Channel_Id': item['snippet']['channelId'],
                'Channel_Name': item['snippet']['channelTitle'],
                'PublishedAt': item['snippet']['publishedAt'],
                'Video_count': item['contentDetails']['itemCount']
            }
            All_data.append(data)

        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

    return All_data

# %%
playlist = get_playlist_details(youtube,channel_id)

# %%
playlist
# Out:
# []

# %%
import mysql.connector

# MySQL connection configuration
mysql_host = "localhost"
mysql_user = "root"
mysql_password = "YOUR PASSWORD"
mysql_database = "YOUR DATABASE"
mysql_port = "YOUR PORT"

# Function to connect to MySQL database
def connect_to_mysql():
    try:
        conn = mysql.connector.connect(
            host=mysql_host,
            user=mysql_user,
            password=mysql_password,
            database=mysql_database,
            port=mysql_port
        )
        print("Connected to MySQL database successfully")
        return conn
    except mysql.connector.Error as e:
        print("Error connecting to MySQL database:", e)
        return None

# Function to create tables in MySQL
def create_tables(conn):
    cursor = conn.cursor()

    # Table creation queries
    channel_table_query = """
    CREATE TABLE IF NOT EXISTS channel_data (
        Channel_Name VARCHAR(255),
        Channel_Id VARCHAR(255),
        Subscribers INT,
        Views INT,
        Total_videos INT,
        Channel_description TEXT,
        Playlist_Id VARCHAR(255)
    )
    """
    video_table_query = """
    CREATE TABLE IF NOT EXISTS video_data (
        Channel_Name VARCHAR(255),
        Channel_Id VARCHAR(255),
        Video_Id VARCHAR(255),
        Title VARCHAR(255),
        Tags TEXT,
        Thumbnail TEXT,
        Description TEXT,
        Publishdate DATETIME,
        Duration VARCHAR(255),
        Views INT,
        Likes INT,
        Comments INT,
        Favorite_count INT,
        Definition VARCHAR(255),
        Caption_Status VARCHAR(255)
    )
    """
    comment_table_query = """
    CREATE TABLE IF NOT EXISTS comment_data (
        Comment_id VARCHAR(255),
        Video_id VARCHAR(255),
        Comment_text TEXT,
        Comment_Author VARCHAR(255),
        Comment_Published DATETIME
    )
    """
    playlist_table_query = """
    CREATE TABLE IF NOT EXISTS playlist_data (
        Playlist_Id VARCHAR(255),
        Title VARCHAR(255),
        Channel_Id VARCHAR(255),
        Channel_Name VARCHAR(255),
        PublishedAt DATETIME,
        Video_count INT
    )
    """

    try:
        # Execute table creation queries
        cursor.execute(channel_table_query)
        cursor.execute(video_table_query)
        cursor.execute(comment_table_query)
        cursor.execute(playlist_table_query)

        conn.commit()
        print("Tables created successfully in MySQL")
    except mysql.connector.Error as e:
        print("Error creating tables in MySQL:", e)
        conn.rollback()
    finally:
        cursor.close()

# Test the functions
conn = connect_to_mysql()
if conn is not None:
    create_tables(conn)
    conn.close()
# Out:
# Connected to MySQL database successfully
# Tables created successfully in MySQL

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="YOUR PASSWORD",
    database="YOUR DATABASE",
    port="YOUR PORT"
)

# Import necessary libraries
import mysql.connector

# Function to insert channel details into MySQL database
def insert_channel_info_to_mysql(conn, channel_info):
    cursor = conn.cursor()
    try:
        for info in channel_info:
            # SQL INSERT query
            insert_query = """
            INSERT INTO channel_data (Channel_Name, Channel_Id, Subscribers, Views, Total_videos, Channel_description, Playlist_Id) 
            VALUES (%s, %s, %s, %s, %s, %s, %s)
            """
            # Execute the query with data from the channel_info list
            cursor.execute(insert_query, (info["Channel_Name"], info["Channel_Id"], info["Subscribers"], info["Views"], info["Total_videos"], info["Channel_description"], info["Playlist_Id"]))
        
        # Commit the changes to the database
        conn.commit()
        print("Channel info inserted into MySQL successfully!")
    except mysql.connector.Error as e:
        print("Error inserting channel info into MySQL:", e)
        conn.rollback()
    finally:
        cursor.close()



# Call the function to insert channel info into MySQL
insert_channel_info_to_mysql(conn, channel_data)
# Out:
# Channel info inserted into MySQL successfully!

# %%
import mysql.connector


# Function to insert video data into MySQL database
def insert_video_data_to_mysql(conn, video_data):
    cursor = conn.cursor()
    try:
        for data in video_data:
            tags = data.get('Tags', [])
            if not isinstance(tags, list):
                tags = [tags]  
            tags = [tag for tag in tags if tag is not None]
            # SQL INSERT query
            insert_query = """
            INSERT INTO Video_data (Channel_Name, Channel_Id, Video_Id, Title, Tags, Thumbnail, Description, Publishdate, Duration, Views, Likes, Comments, Favorite_count, Definition, Caption_Status) 
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """
            # Execute the query with data from the video_data list
            cursor.execute(insert_query, (
                data['Channel_Name'],
                data['channel_Id'],
                data['Video_Id'],
                data['Title'],
                ",".join(tags),  
                data['Thumbnail'],
                data.get('Description', ''),
                data['Publishdate'],
                data['Duration'],
                data['Views'],
                data.get('Likes', 0),  
                data.get('Comments', 0),  
                data.get('Favorite_count', 0),  
                data['Definition'],
                data['Caption_Status']
            ))
        
        # Commit the changes to the database
        conn.commit()
        print("Video data inserted into MySQL successfully!")
    except mysql.connector.Error as e:
        print("Error inserting video data into MySQL:", e)
        conn.rollback()
    finally:
        cursor.close()


video2 = get_Video_Details(youtube,Video_data)

# Call the function to insert video data into MySQL
insert_video_data_to_mysql(conn, video2)
# Out:
# Video data inserted into MySQL successfully!

# %%
import mysql.connector

# Function to insert comment data into MySQL database
def insert_comment_data_to_mysql(conn, comment_data):
    cursor = conn.cursor()
    try:
        for data in comment_data:
            # SQL INSERT query
            insert_query = """
            INSERT INTO comment_data (Comment_id, Video_id, Comment_text, Comment_Author, Comment_Published) 
            VALUES (%s, %s, %s, %s, %s)
            """
            # Execute the query with data from the comment_data list
            cursor.execute(insert_query, (
                data['Comment_id'],
                data['Video_id'],
                data['Comment_text'],
                data['Comment_Author'],
                data['Comment_Published']
            ))
        
        # Commit the changes to the database
        conn.commit()
        print("Comment data inserted into MySQL successfully!")
    except mysql.connector.Error as e:
        print("Error inserting comment data into MySQL:", e)
        conn.rollback()
    finally:
        cursor.close()


comment_data = get_comment_Details(youtube, Video_data)

# Call the function to insert comment data into MySQL
insert_comment_data_to_mysql(conn, comment_data)
# Out:
# Comment data inserted into MySQL successfully!

# %%
import mysql.connector
import datetime  # Import the datetime module

# Function to insert playlist data into MySQL database
def insert_playlist_data_to_mysql(conn, playlist_data):
    cursor = conn.cursor()
    try:
        for data in playlist_data:
            # SQL INSERT query
            insert_query = """
            INSERT INTO playlist_data (Playlist_Id, Title, Channel_Id, Channel_Name, PublishedAt, Video_count) 
            VALUES (%s, %s, %s, %s, %s, %s)
            """
            # Execute the query with data from the playlist_data list
            cursor.execute(insert_query, (
                data['Playlist_Id'],
                data['Title'],
                data['Channel_Id'],
                data['Channel_Name'],
                data['PublishedAt'],
                data['Video_count']
            ))
        
        # Commit the changes to the database
        conn.commit()
        print("Playlist data inserted into MySQL successfully!")
    except mysql.connector.Error as e:
        print("Error inserting playlist data into MySQL:", e)
        conn.rollback()
    finally:
        cursor.close()


playlist_data = get_playlist_details(youtube, channel_id)

# Call the function to insert playlist data into MySQL
insert_playlist_data_to_mysql(conn, playlist_data)
# Out:
# Playlist data inserted into MySQL successfully!
